# %%
import librosa
import soundfile as sf
import pandas as pd
import numpy as np
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit


import soundfile as sf

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns 

import librosa
import librosa.display

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-07-30 23:04:04.402910: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#creating 6 second sengments of audio samples used previously to create more data

# %%
def trim_audio_files(input_folder, output_folder):
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each genre subfolder
    genres = os.listdir(input_folder)
    for genre in genres:
        genre_folder = os.path.join(input_folder, genre)

        # Check if it's a directory
        if not os.path.isdir(genre_folder):
            continue

        # subfolder for the genre in the output folder
        genre_output_folder = os.path.join(output_folder, genre)
        if not os.path.exists(genre_output_folder):
            os.makedirs(genre_output_folder)

        # Looping through each audio file in the genre folder that ends with .wav
        audio_files = [f for f in os.listdir(genre_folder) if f.endswith(".wav") and not f.startswith(".")]
        for audio_file in audio_files:
            input_file_path = os.path.join(genre_folder, audio_file)

            # Loading audio file
            audio, sr = librosa.load(input_file_path, sr=None)

            # creating 6 second clips/segments of audio
            segment_duration = 6  
            num_segments = len(audio) // (sr * segment_duration)

            # Looping through the audio and creating new files for each segment
            for i in range(num_segments):
                start_sample = i * sr * segment_duration
                end_sample = (i + 1) * sr * segment_duration

                # Extract the segment
                segment = audio[start_sample:end_sample]

                output_file = os.path.join(genre_output_folder, f"{audio_file[:-4]}_segment_{i + 1}.wav")

                # Save the segment as a new WAV file using soundfile
                sf.write(output_file, segment, sr)

    print(f"Trimmed segments for all genres created and saved in {output_folder}")

# %%
#input_folder = "/Users/kellyjara/Desktop/Test Data/genres_original"
#output_folder = "/Users/kellyjara/Desktop/Test Data/genres_trimmed"
#trim_audio_files(input_folder, output_folder)

# %%
def melspec_features(audio_path, sr=22050, n_mels=64, hop_length=400, n_frames=1, n_fft=1024):

    #loading audio file
    y, sr = librosa.load(audio_path)  
    #creating melspec feature
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft = n_fft,
                                          hop_length = hop_length, n_mels = n_mels)
    #normalizing mel spectrogram
    mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
    
    #pad/truncating to ensure all audio samples have the same length prior to running through the model
    mel_spectrogram = np.pad(mel_spectrogram, ((0, 0), (0, max(0, n_frames - mel_spectrogram.shape[1]))), 
                             mode='constant')
    mel_spectrogram = mel_spectrogram[:, :n_frames]
    
    return mel_spectrogram

# %%
def load_audio_files(data_dir, genres):
    #creating empty list
    all_mel_spectrograms = []
    all_labels = []
    
    for genre_index, genre in enumerate(genres):
        genre_dir = os.path.join(directory, genre)
        audio_files = os.listdir(genre_dir)

        for audio_file in audio_files:
            audio_path = os.path.join(genre_dir, audio_file)
            #looping through files making sure it ends with .wav (have hidden files within the directory)
            if os.path.isfile(audio_path) and audio_file.lower().endswith(('.wav')):
                mel_spectrogram = melspec_features(audio_path)

                all_mel_spectrograms.append(mel_spectrogram)
                all_labels.append(genre_index)

    all_mel_spectrograms = np.array(all_mel_spectrograms)
    all_labels = np.array(all_labels)

    return all_mel_spectrograms, all_labels

# %%
directory = '/Users/kellyjara/Desktop/Test Data/genres_trimmed'
genres = ['blues', 'classical', 'country', 'disco','hiphop', 'jazz','metal', 'pop', 'reggae', 'rock']

all_mel_spectrograms, all_labels = load_audio_files(directory, genres)

# %%
#reshapping to create df with info
reshaped_mel_spectrograms = [mel_spectrogram.ravel() for mel_spectrogram in all_mel_spectrograms]

spectrogram_series = [pd.Series(mel_spectrogram) for mel_spectrogram in reshaped_mel_spectrograms]

df = pd.concat([pd.DataFrame(spectrogram_series), pd.Series(all_labels, name='label')], axis=1)

# %%
df
# Out:
#               0          1          2          3          4          5  \
# 0    -14.251838 -13.122309 -17.378595 -19.016870 -19.089672 -17.880081
# 1    -12.428816 -17.256380 -18.799641 -19.021170 -19.608223 -22.834064
# 2     -7.222175  -7.465009  -9.467773 -15.350006 -24.655840 -22.813179
# 3    -13.839224 -13.039390 -18.652845 -29.813875 -20.888809 -16.828560
# 4    -19.986414 -22.005198 -18.739420 -18.591976 -15.725191 -22.208080
# ...         ...        ...        ...        ...        ...        ...
# 6982 -13.378391 -10.708499 -15.370485 -11.596584 -12.495448 -16.466030
# 6983 -18.467232 -16.839695 -13.625200 -16.526506 -24.118832 -33.124847
# 6984  -6.984684  -9.222915 -11.196207 -10.992528 -15.453659 -21.275131
# 6985 -17.453598 -16.001034 -19.410364 -22.572104 -24.987122 -31.891487
# 6986 -22.166027 -18.917797 -23.409132 -19.344957 -15.765631 -20.687204
#
#               6          7          8          9  ...         55         56  \
# 0    -23.351181 -32.613007 -34.962963 -30.712912  ... -42.086105 -43.506081
# 1    -16.038242  -8.856348  -7.850418 -16.071945  ... -46.514069 -48.036354
# 2    -20.164675 -23.900408 -38.443485 -31.208973  ... -53.659267 -54.747837
# 3    -19.395489 -26.127188 -29.592663 -31.395107  ... -54.769577 -53.704842
# 4    -28.902262 -24.956005 -20.785997 -16.100275  ... -43.896725 -46.755569
# ...         ...        ...        ...        ...  ...        ...        ...
# 6982 -21.985592 -14.784528 -16.598976 -19.682400  ... -45.647564 -47.738373
# 6983 -34.478302 -30.374168 -32.384529 -37.375149  ... -45.114441 -44.281456
# 6984 -18.631214 -18.427641 -27.493244 -25.264580  ... -46.526024 -49.678352
# 6985 -37.920929 -25.246262 -18.473724 -22.237137  ... -48.276230 -53.166828
# 6986 -21.477903 -22.653286 -10.858968  -5.866035  ... -44.157162 -44.889080
#
#              57         58         59         60         61         62  \
# 0    -39.105614 -39.922958 -40.942955 -42.006210 -42.275425 -41.509205
# 1    -49.952156 -51.625275 -53.129398 -52.573864 -55.373749 -53.135368
# 2    -60.761158 -61.606316 -57.550751 -58.037479 -60.899445 -59.296982
# 3    -53.416397 -53.807476 -55.259468 -54.551189 -56.562866 -57.151756
# 4    -52.995403 -55.550240 -53.113583 -56.862617 -61.081062 -61.500278
# ...         ...        ...        ...        ...        ...        ...
# 6982 -49.398979 -49.625301 -46.350544 -46.979458 -45.527466 -46.959904
# 6983 -41.380348 -45.138222 -52.663433 -55.906128 -61.424278 -72.231430
# 6984 -49.137489 -52.539230 -52.193123 -50.913567 -54.511108 -56.806702
# 6985 -50.687626 -51.501633 -49.681099 -48.311752 -52.811054 -56.392250
# 6986 -42.185532 -47.433311 -45.860374 -48.717384 -51.473309 -52.321617
#
#              63  label
# 0    -44.791512      0
# 1    -55.536079      0
# 2    -62.759602      0
# 3    -60.965576      0
# 4    -61.719170      0
# ...         ...    ...
# 6982 -45.310547      9
# 6983 -77.239876      9
# 6984 -59.181122      9
# 6985 -57.144054      9
# 6986 -52.474659      9
#
# [6987 rows x 65 columns]

# %%
X = df.drop('label', axis=1).values
y = df['label'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .20)

# %%
scaler = StandardScaler()

X_train_sc = scaler.fit_transform(np.array(X_train, dtype = float))
X_val_sc = scaler.transform(np.array(X_val, dtype = float))
X_test_sc = scaler.transform(np.array(X_test, dtype = float))

# %%
X_train_reshaped = X_train_sc.reshape((X_train_sc.shape[0], 1, X_train_sc.shape[1]))
X_test_reshaped = X_test_sc.reshape(X_test_sc.shape[0], 1, X_test_sc.shape[1])
X_val_reshaped = X_val_sc.reshape(X_val_sc.shape[0], 1, X_val_sc.shape[1])

# %%
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.LSTM(units=64),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=32, activation='relu'),  
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 19/19 [==============================] - 22s 752ms/step - loss: 2.2331 - accuracy: 0.1622 - val_loss: 2.1907 - val_accuracy: 0.1756
# Epoch 2/50
# 19/19 [==============================] - 14s 740ms/step - loss: 2.1648 - accuracy: 0.1913 - val_loss: 2.1166 - val_accuracy: 0.2080
# Epoch 3/50
# 19/19 [==============================] - 14s 713ms/step - loss: 2.1207 - accuracy: 0.2197 - val_loss: 2.0993 - val_accuracy: 0.2166
# Epoch 4/50
# 19/19 [==============================] - 13s 692ms/step - loss: 2.1013 - accuracy: 0.2302 - val_loss: 2.0742 - val_accuracy: 0.2319
# Epoch 5/50
# 19/19 [==============================] - 12s 646ms/step - loss: 2.0848 - accuracy: 0.2326 - val_loss: 2.0628 - val_accuracy: 0.2271
# Epoch 6/50
# 19/19 [==============================] - 12s 643ms/step - loss: 2.0763 - accuracy: 0.2531 - val_loss: 2.0500 - val_accuracy: 0.2452
# Epoch 7/50
# 19/19 [==============================] - 11s 589ms/step - loss: 2.0452 - accuracy: 0.2567 - val_loss: 2.0290 - val_accuracy: 0.2357
# Epoch 8/50
# 19/19 [==============================] - 11s 587ms/step - loss: 2.0468 - accuracy: 0.2536 - val_loss: 2.0344 - val_accuracy: 0.2414
# Epoch 9/50
# 19/19 [==============================] - 11s 590ms/step - loss: 2.0237 - accuracy: 0.2638 - val_loss: 2.0311 - val_accuracy: 0.2576
# Epoch 10/50
# 19/19 [==============================] - 11s 588ms/step - loss: 2.0245 - accuracy: 0.2657 - val_loss: 2.0239 - val_accuracy: 0.2557
# Epoch 11/50
# 19/19 [==============================] - 11s 582ms/step - loss: 2.0119 - accuracy: 0.2736 - val_loss: 2.0057 - val_accuracy: 0.2529
# Epoch 12/50
# 19/19 [==============================] - 11s 589ms/step - loss: 2.0083 - accuracy: 0.2679 - val_loss: 1.9894 - val_accuracy: 0.2653
# Epoch 13/50
# 19/19 [==============================] - 11s 594ms/step - loss: 1.9947 - accuracy: 0.2777 - val_loss: 1.9994 - val_accuracy: 0.2691
# Epoch 14/50
# 19/19 [==============================] - 11s 590ms/step - loss: 1.9826 - accuracy: 0.2812 - val_loss: 1.9804 - val_accuracy: 0.2805
# Epoch 15/50
# 19/19 [==============================] - 11s 598ms/step - loss: 1.9795 - accuracy: 0.2896 - val_loss: 1.9855 - val_accuracy: 0.2624
# Epoch 16/50
# 19/19 [==============================] - 11s 592ms/step - loss: 1.9714 - accuracy: 0.2915 - val_loss: 1.9818 - val_accuracy: 0.2872
# Epoch 17/50
# 19/19 [==============================] - 11s 600ms/step - loss: 1.9576 - accuracy: 0.2875 - val_loss: 1.9768 - val_accuracy: 0.2605
# Epoch 18/50
# 19/19 [==============================] - 12s 619ms/step - loss: 1.9698 - accuracy: 0.2860 - val_loss: 1.9784 - val_accuracy: 0.2481
# Epoch 19/50
# 19/19 [==============================] - 11s 595ms/step - loss: 1.9456 - accuracy: 0.2982 - val_loss: 1.9808 - val_accuracy: 0.2758
# Epoch 20/50
# 19/19 [==============================] - 11s 586ms/step - loss: 1.9408 - accuracy: 0.2987 - val_loss: 1.9535 - val_accuracy: 0.2758
# Epoch 21/50
# 19/19 [==============================] - 11s 597ms/step - loss: 1.9474 - accuracy: 0.2999 - val_loss: 1.9761 - val_accuracy: 0.2729
# Epoch 22/50
# 19/19 [==============================] - 11s 592ms/step - loss: 1.9476 - accuracy: 0.2891 - val_loss: 1.9518 - val_accuracy: 0.2815
# Epoch 23/50
# 19/19 [==============================] - 11s 608ms/step - loss: 1.9222 - accuracy: 0.2999 - val_loss: 1.9427 - val_accuracy: 0.2853
# Epoch 24/50
# 19/19 [==============================] - 11s 592ms/step - loss: 1.9314 - accuracy: 0.2946 - val_loss: 1.9649 - val_accuracy: 0.2748
# Epoch 25/50
# 19/19 [==============================] - 11s 593ms/step - loss: 1.9410 - accuracy: 0.2908 - val_loss: 1.9413 - val_accuracy: 0.2929
# Epoch 26/50
# 19/19 [==============================] - 11s 605ms/step - loss: 1.9392 - accuracy: 0.2922 - val_loss: 1.9593 - val_accuracy: 0.2777
# Epoch 27/50
# 19/19 [==============================] - 11s 603ms/step - loss: 1.9379 - accuracy: 0.2977 - val_loss: 1.9501 - val_accuracy: 0.2891
# Epoch 28/50
# 19/19 [==============================] - 11s 600ms/step - loss: 1.9279 - accuracy: 0.3077 - val_loss: 1.9388 - val_accuracy: 0.2758
# Epoch 29/50
# 19/19 [==============================] - 11s 597ms/step - loss: 1.9134 - accuracy: 0.3006 - val_loss: 1.9544 - val_accuracy: 0.2739
# Epoch 30/50
# 19/19 [==============================] - 11s 602ms/step - loss: 1.9113 - accuracy: 0.3030 - val_loss: 1.9372 - val_accuracy: 0.2796
# Epoch 31/50
# 19/19 [==============================] - 11s 603ms/step - loss: 1.8939 - accuracy: 0.3087 - val_loss: 1.9200 - val_accuracy: 0.2929
# Epoch 32/50
# 19/19 [==============================] - 11s 601ms/step - loss: 1.8970 - accuracy: 0.3163 - val_loss: 1.9594 - val_accuracy: 0.2872
# Epoch 33/50
# 19/19 [==============================] - 11s 597ms/step - loss: 1.9101 - accuracy: 0.3123 - val_loss: 1.9403 - val_accuracy: 0.2891
# Epoch 34/50
# 19/19 [==============================] - 11s 605ms/step - loss: 1.8859 - accuracy: 0.3151 - val_loss: 1.9481 - val_accuracy: 0.2939
# Epoch 35/50
# 19/19 [==============================] - 12s 612ms/step - loss: 1.8922 - accuracy: 0.3080 - val_loss: 1.9541 - val_accuracy: 0.2853
# Epoch 36/50
# 19/19 [==============================] - 11s 591ms/step - loss: 1.9010 - accuracy: 0.3075 - val_loss: 1.9329 - val_accuracy: 0.2929
# Epoch 37/50
# 19/19 [==============================] - 11s 597ms/step - loss: 1.8716 - accuracy: 0.3228 - val_loss: 1.9506 - val_accuracy: 0.2863
# Epoch 38/50
# 19/19 [==============================] - 11s 599ms/step - loss: 1.8713 - accuracy: 0.3192 - val_loss: 1.9418 - val_accuracy: 0.2929
# Epoch 39/50
# 19/19 [==============================] - 11s 594ms/step - loss: 1.8720 - accuracy: 0.3213 - val_loss: 1.9204 - val_accuracy: 0.2853
# Epoch 40/50
# 19/19 [==============================] - 10s 537ms/step - loss: 1.8786 - accuracy: 0.3142 - val_loss: 1.9433 - val_accuracy: 0.2901
# Epoch 41/50
# 19/19 [==============================] - 13s 676ms/step - loss: 1.8929 - accuracy: 0.3187 - val_loss: 1.9363 - val_accuracy: 0.2968
# Epoch 42/50
# 19/19 [==============================] - 9s 447ms/step - loss: 1.8623 - accuracy: 0.3275 - val_loss: 1.9260 - val_accuracy: 0.3006
# Epoch 43/50
# 19/19 [==============================] - 7s 391ms/step - loss: 1.8500 - accuracy: 0.3232 - val_loss: 1.9185 - val_accuracy: 0.2901
# Epoch 44/50
# 19/19 [==============================] - 7s 393ms/step - loss: 1.8339 - accuracy: 0.3213 - val_loss: 1.9168 - val_accuracy: 0.2939
# Epoch 45/50
# 19/19 [==============================] - 7s 396ms/step - loss: 1.8372 - accuracy: 0.3309 - val_loss: 1.9071 - val_accuracy: 0.2958
# Epoch 46/50
# 19/19 [==============================] - 8s 395ms/step - loss: 1.8306 - accuracy: 0.3311 - val_loss: 1.9201 - val_accuracy: 0.3063
# Epoch 47/50
# 19/19 [==============================] - 7s 396ms/step - loss: 1.8318 - accuracy: 0.3304 - val_loss: 1.9302 - val_accuracy: 0.2968
# Epoch 48/50
# 19/19 [==============================] - 7s 394ms/step - loss: 1.8306 - accuracy: 0.3411 - val_loss: 1.9088 - val_accuracy: 0.3006
# Epoch 49/50
# 19/19 [==============================] - 7s 394ms/step - loss: 1.8308 - accuracy: 0.3423 - val_loss: 1.9270 - val_accuracy: 0.2863
# Epoch 50/50
# 19/19 [==============================] - 7s 391ms/step - loss: 1.8078 - accuracy: 0.3438 - val_loss: 1.8991 - val_accuracy: 0.3025

# %%
loss, accuracy = model.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
# Out:
# 131/131 [==============================] - 4s 31ms/step - loss: 1.7386 - accuracy: 0.3662
# :loss: 1.7385785579681396, accuracy: 0.366173654794693

# %%
test_loss = model.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 33/33 [==============================] - 1s 30ms/step - loss: 1.8991 - accuracy: 0.3025
# Test Loss: [1.8991410732269287, 0.30248090624809265]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %%
### rnn model with regularization 
from tensorflow.keras.regularizers import L2

reg_lambda = 0.01  # Regularization strength

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True,
                         kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(units=64, kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=32, activation='relu', kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax', kernel_regularizer=L2(reg_lambda))
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 19/19 [==============================] - 13s 446ms/step - loss: 4.1836 - accuracy: 0.1560 - val_loss: 3.7809 - val_accuracy: 0.1718
# Epoch 2/50
# 19/19 [==============================] - 7s 395ms/step - loss: 3.4968 - accuracy: 0.1854 - val_loss: 3.2190 - val_accuracy: 0.1899
# Epoch 3/50
# 19/19 [==============================] - 7s 392ms/step - loss: 3.0430 - accuracy: 0.1944 - val_loss: 2.8701 - val_accuracy: 0.2109
# Epoch 4/50
# 19/19 [==============================] - 7s 392ms/step - loss: 2.7458 - accuracy: 0.2252 - val_loss: 2.6293 - val_accuracy: 0.2261
# Epoch 5/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.5663 - accuracy: 0.2276 - val_loss: 2.4961 - val_accuracy: 0.2137
# Epoch 6/50
# 19/19 [==============================] - 7s 392ms/step - loss: 2.4443 - accuracy: 0.2347 - val_loss: 2.3973 - val_accuracy: 0.2252
# Epoch 7/50
# 19/19 [==============================] - 7s 393ms/step - loss: 2.3457 - accuracy: 0.2524 - val_loss: 2.3469 - val_accuracy: 0.2176
# Epoch 8/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.3007 - accuracy: 0.2436 - val_loss: 2.3177 - val_accuracy: 0.2281
# Epoch 9/50
# 19/19 [==============================] - 7s 392ms/step - loss: 2.2600 - accuracy: 0.2455 - val_loss: 2.2455 - val_accuracy: 0.2395
# Epoch 10/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.2283 - accuracy: 0.2498 - val_loss: 2.2344 - val_accuracy: 0.2223
# Epoch 11/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.2108 - accuracy: 0.2543 - val_loss: 2.2146 - val_accuracy: 0.2252
# Epoch 12/50
# 19/19 [==============================] - 7s 395ms/step - loss: 2.1850 - accuracy: 0.2538 - val_loss: 2.2089 - val_accuracy: 0.2261
# Epoch 13/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.1681 - accuracy: 0.2567 - val_loss: 2.2131 - val_accuracy: 0.2176
# Epoch 14/50
# 19/19 [==============================] - 8s 397ms/step - loss: 2.1698 - accuracy: 0.2572 - val_loss: 2.1696 - val_accuracy: 0.2357
# Epoch 15/50
# 19/19 [==============================] - 7s 395ms/step - loss: 2.1467 - accuracy: 0.2600 - val_loss: 2.1585 - val_accuracy: 0.2414
# Epoch 16/50
# 19/19 [==============================] - 7s 395ms/step - loss: 2.1388 - accuracy: 0.2681 - val_loss: 2.1588 - val_accuracy: 0.2385
# Epoch 17/50
# 19/19 [==============================] - 7s 394ms/step - loss: 2.1310 - accuracy: 0.2624 - val_loss: 2.1586 - val_accuracy: 0.2405
# Epoch 18/50
# 19/19 [==============================] - 9s 473ms/step - loss: 2.1214 - accuracy: 0.2700 - val_loss: 2.1503 - val_accuracy: 0.2385
# Epoch 19/50
# 19/19 [==============================] - 9s 454ms/step - loss: 2.1133 - accuracy: 0.2626 - val_loss: 2.1336 - val_accuracy: 0.2414
# Epoch 20/50
# 19/19 [==============================] - 9s 456ms/step - loss: 2.1043 - accuracy: 0.2715 - val_loss: 2.1441 - val_accuracy: 0.2490
# Epoch 21/50
# 19/19 [==============================] - 9s 468ms/step - loss: 2.1143 - accuracy: 0.2662 - val_loss: 2.1551 - val_accuracy: 0.2338
# Epoch 22/50
# 19/19 [==============================] - 9s 471ms/step - loss: 2.0967 - accuracy: 0.2760 - val_loss: 2.1310 - val_accuracy: 0.2414
# Epoch 23/50
# 19/19 [==============================] - 8s 429ms/step - loss: 2.0888 - accuracy: 0.2779 - val_loss: 2.1140 - val_accuracy: 0.2538
# Epoch 24/50
# 19/19 [==============================] - 9s 459ms/step - loss: 2.1033 - accuracy: 0.2693 - val_loss: 2.1427 - val_accuracy: 0.2309
# Epoch 25/50
# 19/19 [==============================] - 9s 456ms/step - loss: 2.0983 - accuracy: 0.2669 - val_loss: 2.1161 - val_accuracy: 0.2481
# Epoch 26/50
# 19/19 [==============================] - 9s 449ms/step - loss: 2.0853 - accuracy: 0.2801 - val_loss: 2.1213 - val_accuracy: 0.2510
# Epoch 27/50
# 19/19 [==============================] - 9s 453ms/step - loss: 2.0789 - accuracy: 0.2820 - val_loss: 2.1001 - val_accuracy: 0.2529
# Epoch 28/50
# 19/19 [==============================] - 8s 439ms/step - loss: 2.0702 - accuracy: 0.2832 - val_loss: 2.1183 - val_accuracy: 0.2529
# Epoch 29/50
# 19/19 [==============================] - 9s 478ms/step - loss: 2.0898 - accuracy: 0.2705 - val_loss: 2.1180 - val_accuracy: 0.2557
# Epoch 30/50
# 19/19 [==============================] - 9s 484ms/step - loss: 2.0722 - accuracy: 0.2836 - val_loss: 2.1033 - val_accuracy: 0.2691
# Epoch 31/50
# 19/19 [==============================] - 9s 476ms/step - loss: 2.0692 - accuracy: 0.2836 - val_loss: 2.0984 - val_accuracy: 0.2529
# Epoch 32/50
# 19/19 [==============================] - 10s 524ms/step - loss: 2.0667 - accuracy: 0.2903 - val_loss: 2.1006 - val_accuracy: 0.2576
# Epoch 33/50
# 19/19 [==============================] - 9s 482ms/step - loss: 2.0578 - accuracy: 0.2886 - val_loss: 2.0906 - val_accuracy: 0.2643
# Epoch 34/50
# 19/19 [==============================] - 10s 511ms/step - loss: 2.0558 - accuracy: 0.2846 - val_loss: 2.0887 - val_accuracy: 0.2500
# Epoch 35/50
# 19/19 [==============================] - 9s 480ms/step - loss: 2.0502 - accuracy: 0.2839 - val_loss: 2.0915 - val_accuracy: 0.2691
# Epoch 36/50
# 19/19 [==============================] - 10s 545ms/step - loss: 2.0491 - accuracy: 0.2889 - val_loss: 2.0838 - val_accuracy: 0.2548
# Epoch 37/50
# 19/19 [==============================] - 10s 552ms/step - loss: 2.0393 - accuracy: 0.3008 - val_loss: 2.0898 - val_accuracy: 0.2615
# Epoch 38/50
# 19/19 [==============================] - 10s 518ms/step - loss: 2.0412 - accuracy: 0.2989 - val_loss: 2.0989 - val_accuracy: 0.2452
# Epoch 39/50
# 19/19 [==============================] - 9s 487ms/step - loss: 2.0390 - accuracy: 0.2958 - val_loss: 2.0710 - val_accuracy: 0.2805
# Epoch 40/50
# 19/19 [==============================] - 9s 484ms/step - loss: 2.0280 - accuracy: 0.3013 - val_loss: 2.0740 - val_accuracy: 0.2700
# Epoch 41/50
# 19/19 [==============================] - 9s 487ms/step - loss: 2.0373 - accuracy: 0.3015 - val_loss: 2.0789 - val_accuracy: 0.2691
# Epoch 42/50
# 19/19 [==============================] - 9s 479ms/step - loss: 2.0412 - accuracy: 0.2917 - val_loss: 2.0832 - val_accuracy: 0.2605
# Epoch 43/50
# 19/19 [==============================] - 9s 480ms/step - loss: 2.0349 - accuracy: 0.3044 - val_loss: 2.0914 - val_accuracy: 0.2634
# Epoch 44/50
# 19/19 [==============================] - 9s 481ms/step - loss: 2.0293 - accuracy: 0.2922 - val_loss: 2.0698 - val_accuracy: 0.2739
# Epoch 45/50
# 19/19 [==============================] - 9s 480ms/step - loss: 2.0403 - accuracy: 0.3001 - val_loss: 2.0790 - val_accuracy: 0.2710
# Epoch 46/50
# 19/19 [==============================] - 9s 482ms/step - loss: 2.0221 - accuracy: 0.3037 - val_loss: 2.0656 - val_accuracy: 0.2700
# Epoch 47/50
# 19/19 [==============================] - 9s 478ms/step - loss: 2.0215 - accuracy: 0.3022 - val_loss: 2.1034 - val_accuracy: 0.2672
# Epoch 48/50
# 19/19 [==============================] - 9s 484ms/step - loss: 2.0172 - accuracy: 0.3123 - val_loss: 2.0778 - val_accuracy: 0.2605
# Epoch 49/50
# 19/19 [==============================] - 9s 479ms/step - loss: 2.0178 - accuracy: 0.3070 - val_loss: 2.0870 - val_accuracy: 0.2624
# Epoch 50/50
# 19/19 [==============================] - 9s 499ms/step - loss: 2.0194 - accuracy: 0.3058 - val_loss: 2.0619 - val_accuracy: 0.2748

# %%
loss, accuracy = model.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 131/131 [==============================] - 5s 41ms/step - loss: 1.9788 - accuracy: 0.3261
# :loss: 1.978839635848999, accuracy: 0.3260973393917084
# 33/33 [==============================] - 1s 40ms/step - loss: 2.0619 - accuracy: 0.2748
# Test Loss: [2.061898946762085, 0.2748091518878937]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %%
reg_lambda = 0.01

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train.shape[1], 1), return_sequences=True,
                         kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(units=64, kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=32, activation='sigmoid', kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax', kernel_regularizer=L2(reg_lambda))
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_sc, y_train, epochs=150, batch_size=300, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/150
# 14/14 [==============================] - 12s 575ms/step - loss: 4.4605 - accuracy: 0.1119 - val_loss: 4.0561 - val_accuracy: 0.1489
# Epoch 2/150
# 14/14 [==============================] - 7s 498ms/step - loss: 3.8067 - accuracy: 0.1374 - val_loss: 3.5176 - val_accuracy: 0.1632
# Epoch 3/150
# 14/14 [==============================] - 7s 504ms/step - loss: 3.3765 - accuracy: 0.1696 - val_loss: 3.1615 - val_accuracy: 0.1889
# Epoch 4/150
# 14/14 [==============================] - 7s 498ms/step - loss: 3.0618 - accuracy: 0.1715 - val_loss: 2.9146 - val_accuracy: 0.2080
# Epoch 5/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.8369 - accuracy: 0.1927 - val_loss: 2.7288 - val_accuracy: 0.2013
# Epoch 6/150
# 14/14 [==============================] - 7s 506ms/step - loss: 2.6730 - accuracy: 0.1982 - val_loss: 2.6049 - val_accuracy: 0.2195
# Epoch 7/150
# 14/14 [==============================] - 9s 643ms/step - loss: 2.5555 - accuracy: 0.2123 - val_loss: 2.5066 - val_accuracy: 0.2261
# Epoch 8/150
# 14/14 [==============================] - 9s 599ms/step - loss: 2.4782 - accuracy: 0.2145 - val_loss: 2.4469 - val_accuracy: 0.2242
# Epoch 9/150
# 14/14 [==============================] - 8s 573ms/step - loss: 2.4297 - accuracy: 0.2125 - val_loss: 2.3871 - val_accuracy: 0.2462
# Epoch 10/150
# 14/14 [==============================] - 7s 495ms/step - loss: 2.3792 - accuracy: 0.2240 - val_loss: 2.3553 - val_accuracy: 0.2376
# Epoch 11/150
# 14/14 [==============================] - 7s 494ms/step - loss: 2.3511 - accuracy: 0.2154 - val_loss: 2.3351 - val_accuracy: 0.2290
# Epoch 12/150
# 14/14 [==============================] - 8s 574ms/step - loss: 2.3179 - accuracy: 0.2228 - val_loss: 2.3087 - val_accuracy: 0.2300
# Epoch 13/150
# 14/14 [==============================] - 7s 514ms/step - loss: 2.3060 - accuracy: 0.2197 - val_loss: 2.2879 - val_accuracy: 0.2252
# Epoch 14/150
# 14/14 [==============================] - 7s 502ms/step - loss: 2.2838 - accuracy: 0.2376 - val_loss: 2.2799 - val_accuracy: 0.2347
# Epoch 15/150
# 14/14 [==============================] - 7s 519ms/step - loss: 2.2695 - accuracy: 0.2247 - val_loss: 2.2633 - val_accuracy: 0.2357
# Epoch 16/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.2658 - accuracy: 0.2295 - val_loss: 2.2636 - val_accuracy: 0.2281
# Epoch 17/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.2600 - accuracy: 0.2273 - val_loss: 2.2444 - val_accuracy: 0.2414
# Epoch 18/150
# 14/14 [==============================] - 7s 512ms/step - loss: 2.2365 - accuracy: 0.2378 - val_loss: 2.2379 - val_accuracy: 0.2414
# Epoch 19/150
# 14/14 [==============================] - 7s 534ms/step - loss: 2.2229 - accuracy: 0.2448 - val_loss: 2.2271 - val_accuracy: 0.2433
# Epoch 20/150
# 14/14 [==============================] - 7s 533ms/step - loss: 2.2240 - accuracy: 0.2345 - val_loss: 2.2412 - val_accuracy: 0.2195
# Epoch 21/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.2291 - accuracy: 0.2290 - val_loss: 2.2340 - val_accuracy: 0.2319
# Epoch 22/150
# 14/14 [==============================] - 7s 502ms/step - loss: 2.2063 - accuracy: 0.2431 - val_loss: 2.2172 - val_accuracy: 0.2357
# Epoch 23/150
# 14/14 [==============================] - 7s 499ms/step - loss: 2.2073 - accuracy: 0.2467 - val_loss: 2.2147 - val_accuracy: 0.2309
# Epoch 24/150
# 14/14 [==============================] - 7s 501ms/step - loss: 2.1989 - accuracy: 0.2433 - val_loss: 2.2137 - val_accuracy: 0.2261
# Epoch 25/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1962 - accuracy: 0.2471 - val_loss: 2.2124 - val_accuracy: 0.2338
# Epoch 26/150
# 14/14 [==============================] - 7s 501ms/step - loss: 2.1976 - accuracy: 0.2459 - val_loss: 2.2028 - val_accuracy: 0.2385
# Epoch 27/150
# 14/14 [==============================] - 7s 499ms/step - loss: 2.1873 - accuracy: 0.2438 - val_loss: 2.2017 - val_accuracy: 0.2261
# Epoch 28/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1839 - accuracy: 0.2376 - val_loss: 2.1894 - val_accuracy: 0.2376
# Epoch 29/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1875 - accuracy: 0.2412 - val_loss: 2.2118 - val_accuracy: 0.2242
# Epoch 30/150
# 14/14 [==============================] - 7s 506ms/step - loss: 2.1827 - accuracy: 0.2459 - val_loss: 2.1965 - val_accuracy: 0.2395
# Epoch 31/150
# 14/14 [==============================] - 7s 502ms/step - loss: 2.1744 - accuracy: 0.2467 - val_loss: 2.1959 - val_accuracy: 0.2261
# Epoch 32/150
# 14/14 [==============================] - 7s 519ms/step - loss: 2.1723 - accuracy: 0.2538 - val_loss: 2.1948 - val_accuracy: 0.2223
# Epoch 33/150
# 14/14 [==============================] - 8s 564ms/step - loss: 2.1737 - accuracy: 0.2474 - val_loss: 2.1865 - val_accuracy: 0.2452
# Epoch 34/150
# 14/14 [==============================] - 7s 497ms/step - loss: 2.1638 - accuracy: 0.2517 - val_loss: 2.1960 - val_accuracy: 0.2328
# Epoch 35/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.1665 - accuracy: 0.2381 - val_loss: 2.2076 - val_accuracy: 0.2214
# Epoch 36/150
# 14/14 [==============================] - 7s 496ms/step - loss: 2.1625 - accuracy: 0.2586 - val_loss: 2.1827 - val_accuracy: 0.2376
# Epoch 37/150
# 14/14 [==============================] - 7s 499ms/step - loss: 2.1598 - accuracy: 0.2498 - val_loss: 2.1855 - val_accuracy: 0.2366
# Epoch 38/150
# 14/14 [==============================] - 7s 527ms/step - loss: 2.1553 - accuracy: 0.2629 - val_loss: 2.1829 - val_accuracy: 0.2281
# Epoch 39/150
# 14/14 [==============================] - 7s 496ms/step - loss: 2.1523 - accuracy: 0.2474 - val_loss: 2.1877 - val_accuracy: 0.2300
# Epoch 40/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.1603 - accuracy: 0.2588 - val_loss: 2.1830 - val_accuracy: 0.2300
# Epoch 41/150
# 14/14 [==============================] - 9s 622ms/step - loss: 2.1599 - accuracy: 0.2524 - val_loss: 2.1850 - val_accuracy: 0.2385
# Epoch 42/150
# 14/14 [==============================] - 8s 564ms/step - loss: 2.1606 - accuracy: 0.2448 - val_loss: 2.1789 - val_accuracy: 0.2471
# Epoch 43/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.1607 - accuracy: 0.2636 - val_loss: 2.1802 - val_accuracy: 0.2414
# Epoch 44/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1562 - accuracy: 0.2550 - val_loss: 2.1758 - val_accuracy: 0.2376
# Epoch 45/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.1416 - accuracy: 0.2593 - val_loss: 2.1734 - val_accuracy: 0.2319
# Epoch 46/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.1462 - accuracy: 0.2569 - val_loss: 2.1710 - val_accuracy: 0.2452
# Epoch 47/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.1404 - accuracy: 0.2495 - val_loss: 2.1930 - val_accuracy: 0.2252
# Epoch 48/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1376 - accuracy: 0.2622 - val_loss: 2.1706 - val_accuracy: 0.2452
# Epoch 49/150
# 14/14 [==============================] - 7s 495ms/step - loss: 2.1340 - accuracy: 0.2665 - val_loss: 2.1589 - val_accuracy: 0.2510
# Epoch 50/150
# 14/14 [==============================] - 8s 582ms/step - loss: 2.1383 - accuracy: 0.2552 - val_loss: 2.1796 - val_accuracy: 0.2319
# Epoch 51/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.1416 - accuracy: 0.2626 - val_loss: 2.1707 - val_accuracy: 0.2462
# Epoch 52/150
# 14/14 [==============================] - 7s 499ms/step - loss: 2.1390 - accuracy: 0.2665 - val_loss: 2.1728 - val_accuracy: 0.2357
# Epoch 53/150
# 14/14 [==============================] - 7s 513ms/step - loss: 2.1356 - accuracy: 0.2672 - val_loss: 2.1919 - val_accuracy: 0.2233
# Epoch 54/150
# 14/14 [==============================] - 7s 509ms/step - loss: 2.1380 - accuracy: 0.2567 - val_loss: 2.1713 - val_accuracy: 0.2309
# Epoch 55/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.1287 - accuracy: 0.2662 - val_loss: 2.1694 - val_accuracy: 0.2395
# Epoch 56/150
# 14/14 [==============================] - 7s 496ms/step - loss: 2.1253 - accuracy: 0.2681 - val_loss: 2.1752 - val_accuracy: 0.2405
# Epoch 57/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.1262 - accuracy: 0.2691 - val_loss: 2.1532 - val_accuracy: 0.2328
# Epoch 58/150
# 14/14 [==============================] - 7s 530ms/step - loss: 2.1318 - accuracy: 0.2617 - val_loss: 2.1578 - val_accuracy: 0.2490
# Epoch 59/150
# 14/14 [==============================] - 9s 687ms/step - loss: 2.1277 - accuracy: 0.2672 - val_loss: 2.1794 - val_accuracy: 0.2385
# Epoch 60/150
# 14/14 [==============================] - 10s 686ms/step - loss: 2.1311 - accuracy: 0.2700 - val_loss: 2.1770 - val_accuracy: 0.2357
# Epoch 61/150
# 14/14 [==============================] - 12s 880ms/step - loss: 2.1234 - accuracy: 0.2765 - val_loss: 2.1626 - val_accuracy: 0.2328
# Epoch 62/150
# 14/14 [==============================] - 17s 1s/step - loss: 2.1401 - accuracy: 0.2638 - val_loss: 2.1612 - val_accuracy: 0.2538
# Epoch 63/150
# 14/14 [==============================] - 15s 1s/step - loss: 2.1314 - accuracy: 0.2631 - val_loss: 2.1647 - val_accuracy: 0.2462
# Epoch 64/150
# 14/14 [==============================] - 9s 624ms/step - loss: 2.1262 - accuracy: 0.2615 - val_loss: 2.1750 - val_accuracy: 0.2385
# Epoch 65/150
# 14/14 [==============================] - 8s 572ms/step - loss: 2.1240 - accuracy: 0.2679 - val_loss: 2.1642 - val_accuracy: 0.2519
# Epoch 66/150
# 14/14 [==============================] - 7s 507ms/step - loss: 2.1137 - accuracy: 0.2770 - val_loss: 2.1596 - val_accuracy: 0.2481
# Epoch 67/150
# 14/14 [==============================] - 8s 548ms/step - loss: 2.1149 - accuracy: 0.2660 - val_loss: 2.1751 - val_accuracy: 0.2414
# Epoch 68/150
# 14/14 [==============================] - 9s 624ms/step - loss: 2.1203 - accuracy: 0.2693 - val_loss: 2.1601 - val_accuracy: 0.2452
# Epoch 69/150
# 14/14 [==============================] - 8s 601ms/step - loss: 2.1287 - accuracy: 0.2636 - val_loss: 2.1969 - val_accuracy: 0.2128
# Epoch 70/150
# 14/14 [==============================] - 8s 540ms/step - loss: 2.1484 - accuracy: 0.2548 - val_loss: 2.1928 - val_accuracy: 0.2319
# Epoch 71/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.1467 - accuracy: 0.2562 - val_loss: 2.1658 - val_accuracy: 0.2510
# Epoch 72/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.1398 - accuracy: 0.2638 - val_loss: 2.1657 - val_accuracy: 0.2481
# Epoch 73/150
# 14/14 [==============================] - 8s 555ms/step - loss: 2.1253 - accuracy: 0.2588 - val_loss: 2.1660 - val_accuracy: 0.2376
# Epoch 74/150
# 14/14 [==============================] - 8s 541ms/step - loss: 2.1269 - accuracy: 0.2626 - val_loss: 2.1796 - val_accuracy: 0.2405
# Epoch 75/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.1270 - accuracy: 0.2648 - val_loss: 2.1695 - val_accuracy: 0.2376
# Epoch 76/150
# 14/14 [==============================] - 7s 518ms/step - loss: 2.1165 - accuracy: 0.2677 - val_loss: 2.1573 - val_accuracy: 0.2414
# Epoch 77/150
# 14/14 [==============================] - 7s 504ms/step - loss: 2.1092 - accuracy: 0.2755 - val_loss: 2.1628 - val_accuracy: 0.2490
# Epoch 78/150
# 14/14 [==============================] - 11s 775ms/step - loss: 2.1068 - accuracy: 0.2765 - val_loss: 2.1525 - val_accuracy: 0.2538
# Epoch 79/150
# 14/14 [==============================] - 8s 580ms/step - loss: 2.1157 - accuracy: 0.2719 - val_loss: 2.1548 - val_accuracy: 0.2519
# Epoch 80/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1204 - accuracy: 0.2729 - val_loss: 2.1554 - val_accuracy: 0.2567
# Epoch 81/150
# 14/14 [==============================] - 7s 496ms/step - loss: 2.1141 - accuracy: 0.2672 - val_loss: 2.1501 - val_accuracy: 0.2548
# Epoch 82/150
# 14/14 [==============================] - 8s 610ms/step - loss: 2.1068 - accuracy: 0.2748 - val_loss: 2.1722 - val_accuracy: 0.2481
# Epoch 83/150
# 14/14 [==============================] - 10s 693ms/step - loss: 2.1043 - accuracy: 0.2789 - val_loss: 2.1560 - val_accuracy: 0.2567
# Epoch 84/150
# 14/14 [==============================] - 7s 485ms/step - loss: 2.0984 - accuracy: 0.2779 - val_loss: 2.1581 - val_accuracy: 0.2529
# Epoch 85/150
# 14/14 [==============================] - 7s 490ms/step - loss: 2.1018 - accuracy: 0.2820 - val_loss: 2.1587 - val_accuracy: 0.2529
# Epoch 86/150
# 14/14 [==============================] - 7s 499ms/step - loss: 2.0924 - accuracy: 0.2917 - val_loss: 2.1528 - val_accuracy: 0.2576
# Epoch 87/150
# 14/14 [==============================] - 7s 487ms/step - loss: 2.0979 - accuracy: 0.2791 - val_loss: 2.1490 - val_accuracy: 0.2624
# Epoch 88/150
# 14/14 [==============================] - 7s 495ms/step - loss: 2.0963 - accuracy: 0.2827 - val_loss: 2.1563 - val_accuracy: 0.2452
# Epoch 89/150
# 14/14 [==============================] - 7s 490ms/step - loss: 2.1000 - accuracy: 0.2822 - val_loss: 2.1522 - val_accuracy: 0.2595
# Epoch 90/150
# 14/14 [==============================] - 7s 493ms/step - loss: 2.0927 - accuracy: 0.2884 - val_loss: 2.1771 - val_accuracy: 0.2443
# Epoch 91/150
# 14/14 [==============================] - 7s 491ms/step - loss: 2.1017 - accuracy: 0.2779 - val_loss: 2.1634 - val_accuracy: 0.2529
# Epoch 92/150
# 14/14 [==============================] - 7s 493ms/step - loss: 2.0924 - accuracy: 0.2827 - val_loss: 2.1508 - val_accuracy: 0.2490
# Epoch 93/150
# 14/14 [==============================] - 7s 492ms/step - loss: 2.0899 - accuracy: 0.2829 - val_loss: 2.1554 - val_accuracy: 0.2500
# Epoch 94/150
# 14/14 [==============================] - 7s 490ms/step - loss: 2.0808 - accuracy: 0.2875 - val_loss: 2.1762 - val_accuracy: 0.2433
# Epoch 95/150
# 14/14 [==============================] - 7s 516ms/step - loss: 2.0855 - accuracy: 0.2855 - val_loss: 2.1546 - val_accuracy: 0.2557
# Epoch 96/150
# 14/14 [==============================] - 9s 691ms/step - loss: 2.0788 - accuracy: 0.3013 - val_loss: 2.1652 - val_accuracy: 0.2433
# Epoch 97/150
# 14/14 [==============================] - 9s 646ms/step - loss: 2.0894 - accuracy: 0.2920 - val_loss: 2.1575 - val_accuracy: 0.2519
# Epoch 98/150
# 14/14 [==============================] - 9s 675ms/step - loss: 2.0848 - accuracy: 0.2960 - val_loss: 2.1500 - val_accuracy: 0.2548
# Epoch 99/150
# 14/14 [==============================] - 9s 674ms/step - loss: 2.0843 - accuracy: 0.2987 - val_loss: 2.1689 - val_accuracy: 0.2405
# Epoch 100/150
# 14/14 [==============================] - 9s 623ms/step - loss: 2.0853 - accuracy: 0.2844 - val_loss: 2.1671 - val_accuracy: 0.2443
# Epoch 101/150
# 14/14 [==============================] - 9s 659ms/step - loss: 2.0809 - accuracy: 0.2910 - val_loss: 2.1547 - val_accuracy: 0.2567
# Epoch 102/150
# 14/14 [==============================] - 11s 839ms/step - loss: 2.0939 - accuracy: 0.2910 - val_loss: 2.1617 - val_accuracy: 0.2424
# Epoch 103/150
# 14/14 [==============================] - 11s 785ms/step - loss: 2.0867 - accuracy: 0.2891 - val_loss: 2.1553 - val_accuracy: 0.2548
# Epoch 104/150
# 14/14 [==============================] - 10s 750ms/step - loss: 2.0808 - accuracy: 0.2956 - val_loss: 2.1439 - val_accuracy: 0.2548
# Epoch 105/150
# 14/14 [==============================] - 10s 701ms/step - loss: 2.0799 - accuracy: 0.2991 - val_loss: 2.1635 - val_accuracy: 0.2576
# Epoch 106/150
# 14/14 [==============================] - 8s 575ms/step - loss: 2.0876 - accuracy: 0.2836 - val_loss: 2.1570 - val_accuracy: 0.2576
# Epoch 107/150
# 14/14 [==============================] - 7s 498ms/step - loss: 2.1124 - accuracy: 0.2786 - val_loss: 2.1487 - val_accuracy: 0.2538
# Epoch 108/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.0954 - accuracy: 0.2867 - val_loss: 2.1624 - val_accuracy: 0.2481
# Epoch 109/150
# 14/14 [==============================] - 7s 500ms/step - loss: 2.0919 - accuracy: 0.2872 - val_loss: 2.1474 - val_accuracy: 0.2576
# Epoch 110/150
# 14/14 [==============================] - 7s 507ms/step - loss: 2.0843 - accuracy: 0.2984 - val_loss: 2.1627 - val_accuracy: 0.2443
# Epoch 111/150
# 14/14 [==============================] - 7s 503ms/step - loss: 2.0791 - accuracy: 0.2922 - val_loss: 2.1689 - val_accuracy: 0.2490
# Epoch 112/150
# 14/14 [==============================] - 9s 621ms/step - loss: 2.0773 - accuracy: 0.2960 - val_loss: 2.1586 - val_accuracy: 0.2548
# Epoch 113/150
# 14/14 [==============================] - 8s 593ms/step - loss: 2.0808 - accuracy: 0.2944 - val_loss: 2.1553 - val_accuracy: 0.2490
# Epoch 114/150
# 14/14 [==============================] - 8s 544ms/step - loss: 2.0822 - accuracy: 0.2972 - val_loss: 2.1634 - val_accuracy: 0.2510
# Epoch 115/150
# 14/14 [==============================] - 8s 550ms/step - loss: 2.0755 - accuracy: 0.2958 - val_loss: 2.1599 - val_accuracy: 0.2557
# Epoch 116/150
# 14/14 [==============================] - 8s 564ms/step - loss: 2.0851 - accuracy: 0.2972 - val_loss: 2.1520 - val_accuracy: 0.2634
# Epoch 117/150
# 14/14 [==============================] - 8s 573ms/step - loss: 2.0778 - accuracy: 0.2932 - val_loss: 2.1654 - val_accuracy: 0.2500
# Epoch 118/150
# 14/14 [==============================] - 8s 586ms/step - loss: 2.0855 - accuracy: 0.2946 - val_loss: 2.1546 - val_accuracy: 0.2405
# Epoch 119/150
# 14/14 [==============================] - 8s 594ms/step - loss: 2.0838 - accuracy: 0.2889 - val_loss: 2.1449 - val_accuracy: 0.2490
# Epoch 120/150
# 14/14 [==============================] - 8s 604ms/step - loss: 2.0836 - accuracy: 0.2996 - val_loss: 2.1634 - val_accuracy: 0.2519
# Epoch 121/150
# 14/14 [==============================] - 8s 539ms/step - loss: 2.0782 - accuracy: 0.2958 - val_loss: 2.1531 - val_accuracy: 0.2595
# Epoch 122/150
# 14/14 [==============================] - 7s 534ms/step - loss: 2.0742 - accuracy: 0.2963 - val_loss: 2.1459 - val_accuracy: 0.2634
# Epoch 123/150
# 14/14 [==============================] - 8s 568ms/step - loss: 2.0842 - accuracy: 0.2932 - val_loss: 2.1642 - val_accuracy: 0.2462
# Epoch 124/150
# 14/14 [==============================] - 8s 556ms/step - loss: 2.0763 - accuracy: 0.2934 - val_loss: 2.1611 - val_accuracy: 0.2538
# Epoch 125/150
# 14/14 [==============================] - 8s 588ms/step - loss: 2.0728 - accuracy: 0.2960 - val_loss: 2.1497 - val_accuracy: 0.2557
# Epoch 126/150
# 14/14 [==============================] - 9s 617ms/step - loss: 2.0723 - accuracy: 0.2944 - val_loss: 2.1620 - val_accuracy: 0.2548
# Epoch 127/150
# 14/14 [==============================] - 9s 611ms/step - loss: 2.1012 - accuracy: 0.2860 - val_loss: 2.1813 - val_accuracy: 0.2443
# Epoch 128/150
# 14/14 [==============================] - 8s 570ms/step - loss: 2.0936 - accuracy: 0.2855 - val_loss: 2.1617 - val_accuracy: 0.2634
# Epoch 129/150
# 14/14 [==============================] - 9s 625ms/step - loss: 2.0753 - accuracy: 0.3006 - val_loss: 2.1522 - val_accuracy: 0.2576
# Epoch 130/150
# 14/14 [==============================] - 10s 742ms/step - loss: 2.0928 - accuracy: 0.2879 - val_loss: 2.1643 - val_accuracy: 0.2443
# Epoch 131/150
# 14/14 [==============================] - 9s 631ms/step - loss: 2.0983 - accuracy: 0.2948 - val_loss: 2.1715 - val_accuracy: 0.2548
# Epoch 132/150
# 14/14 [==============================] - 8s 594ms/step - loss: 2.0837 - accuracy: 0.2989 - val_loss: 2.1502 - val_accuracy: 0.2462
# Epoch 133/150
# 14/14 [==============================] - 8s 609ms/step - loss: 2.0781 - accuracy: 0.2987 - val_loss: 2.1570 - val_accuracy: 0.2615
# Epoch 134/150
# 14/14 [==============================] - 8s 546ms/step - loss: 2.0714 - accuracy: 0.3044 - val_loss: 2.1520 - val_accuracy: 0.2548
# Epoch 135/150
#  7/14 [==============>...............] - ETA: 3s - loss: 2.0693 - accuracy: 0.2962

# %%
loss, accuracy = model.evaluate(X_train, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model.evaluate(X_val, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 131/131 [==============================] - 4s 32ms/step - loss: 1.9391 - accuracy: 0.3547
# :loss: 1.9391006231307983, accuracy: 0.3547232747077942
# 33/33 [==============================] - 1s 31ms/step - loss: 2.1368 - accuracy: 0.2758
# Test Loss: [2.1367955207824707, 0.2757633626461029]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %%
time_steps = 1  
X_train_sc_reshaped = X_train_sc.reshape(X_train_sc.shape[0], time_steps, X_train_sc.shape[1])

model = keras.Sequential([
    layers.Bidirectional(layers.LSTM(units=128, activation='relu', return_sequences=True), input_shape=(time_steps, X_train_sc.shape[1])),
    layers.Bidirectional(layers.LSTM(units=64, activation='Softmax')),
    layers.Dense(1, activation='sigmoid')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model with validation data
history = model.fit(X_train_sc_reshaped, y_train, epochs=20, batch_size=225, verbose=1, validation_data=(X_val_reshaped, y_val))
# Out:
# Epoch 1/20
# 19/19 [==============================] - 12s 100ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 2/20
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 3/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 4/20
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 5/20
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 6/20
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 7/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 8/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 9/20
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 10/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 11/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 12/20
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 13/20
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 14/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 15/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 16/20
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 17/20
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 18/20
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 19/20
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983
# Epoch 20/20
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0000e+00 - accuracy: 0.1004 - val_loss: 0.0000e+00 - val_accuracy: 0.0983

# %%
loss, accuracy = model.evaluate(X_train_sc_reshaped, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model.evaluate(X_val_reshaped, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 131/131 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.1004
# :loss: 0.0, accuracy: 0.10042938590049744
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - accuracy: 0.0983
# Test Loss: [0.0, 0.09828244149684906]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()
