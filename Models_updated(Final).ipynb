# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np 

import os

import soundfile as sf

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns 

import librosa
import librosa.display

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-07-31 14:38:12.016661: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## SKLearn Metrics

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay,RocCurveDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve

# %% [markdown]
# ## Loading DF w/ Extracted Features

# %%
music = pd.read_csv('/Users/kellyjara/Desktop/Music_Classification/Data/music3.csv')
music_df = pd.DataFrame(music)
music_df
# Out:
#                       file_name   mfcc_mean   mfcc_var   mfcc_min   mfcc_max  \
# 0        blues_69_segment_3.wav -135.282870  108.55024  13.028976  43.992382
# 1        blues_27_segment_4.wav  -91.254100  129.46655  -4.100496  45.220657
# 2        blues_54_segment_2.wav -191.496080  139.01646  11.991453  28.216597
# 3        blues_33_segment_1.wav -121.252815  123.47816  13.837003  28.114388
# 4     blues.00009_segment_2.wav -179.017550  138.22562 -30.912750  49.097755
# ...                         ...         ...        ...        ...        ...
# 6982   rock.00063_segment_2.wav -329.291080  139.87671  53.949990  17.256727
# 6983   rock.00004_segment_1.wav -167.203340  143.87451  12.607652  50.331360
# 6984      rock_36_segment_5.wav -269.519000  182.93669   9.128018   7.246886
# 6985      rock_45_segment_3.wav   39.978085   83.57576 -13.916237  31.080480
# 6986   rock.00090_segment_5.wav  -61.516655   99.30332 -26.088478  51.606903
#
#       mfcc1_mean  mfcc1_var  mfcc1_min  mfcc1_max  mfcc2_mean  ...   tntz_min  \
# 0      19.349297  20.206875  -1.577484   7.924092    1.519116  ...  26.657469
# 1       7.252443  16.338186   0.856577   0.009967    1.849428  ...  14.032310
# 2      -0.720076   7.438097   6.724214   6.649870   -0.442536  ...   4.716076
# 3       7.535354  15.141087  -3.699708   6.035746    0.958965  ...  13.126806
# 4     -24.154978   7.536681  -9.466703  10.459454  -20.845018  ...  28.867865
# ...          ...        ...        ...        ...         ...  ...        ...
# 6982   17.011780   9.052016   8.448787   2.826561    0.794122  ...   2.449042
# 6983   -0.389795  35.844570  -3.877623  16.113270   -9.246787  ...  15.285677
# 6984    6.279178  -1.525924  -8.689502   7.118561   -5.731806  ...   0.654456
# 6985    9.406852  10.378225  -1.250743   9.424727   -1.540306  ...  42.720882
# 6986  -32.753830  27.218400 -25.331880  17.409462  -16.120798  ...  15.389015
#
#        tntz_max  melspec_mean  melspec_var  melspec_min  melspec_max  \
# 0     12.485189      9.272328     4.058815    12.436750     7.658901
# 1     25.550907     32.544811     9.085206    45.008915    46.512520
# 2     10.569683     13.037652     0.732540     0.283661     0.217625
# 3     63.396244     21.241156    20.493299    11.539183    11.035036
# 4     17.512299     12.562430    19.704935    44.741116    11.275842
# ...         ...           ...          ...          ...          ...
# 6982   3.578562      1.214767     1.100771     1.418536     1.387431
# 6983  18.517099      7.640218    10.939061    13.667733     5.664557
# 6984   7.530454      1.434070     0.361768     8.512635     1.714976
# 6985  33.466774     29.012289    35.188614    17.988277    31.572403
# 6986   4.966372      5.575272     4.648052     5.028794    10.276192
#
#         rms_mean     rms_var      tempo  genre_y
# 0       3.056901   10.527410   7.565155    blues
# 1     332.813812  129.471909   6.220565    blues
# 2       0.489818    1.817209  13.725842    blues
# 3      10.340260    9.673729   3.113847    blues
# 4       0.719824    0.769180   3.037273    blues
# ...          ...         ...        ...      ...
# 6982    0.550771    0.254566   0.513779     rock
# 6983    9.104764    4.784025   4.133267     rock
# 6984    0.366517    7.676395   1.953892     rock
# 6985   30.429539   89.772820  35.103870     rock
# 6986   42.269131   93.262970  69.886360     rock
#
# [6987 rows x 41 columns]

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6987 entries, 0 to 6986
# Data columns (total 41 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   file_name        6987 non-null   object
#  1   mfcc_mean        6987 non-null   float64
#  2   mfcc_var         6987 non-null   float64
#  3   mfcc_min         6987 non-null   float64
#  4   mfcc_max         6987 non-null   float64
#  5   mfcc1_mean       6987 non-null   float64
#  6   mfcc1_var        6987 non-null   float64
#  7   mfcc1_min        6987 non-null   float64
#  8   mfcc1_max        6987 non-null   float64
#  9   mfcc2_mean       6987 non-null   float64
#  10  mfcc2_var        6987 non-null   float64
#  11  mfcc2_min        6987 non-null   float64
#  12  mfcc2_max        6987 non-null   float64
#  13  delta_mean       6987 non-null   float64
#  14  delta_var        6987 non-null   float64
#  15  delta2_mean      6987 non-null   float64
#  16  delta2_var       6987 non-null   float64
#  17  harmonic_mean    6987 non-null   float64
#  18  harmonic_var     6987 non-null   float64
#  19  percussive_mean  6987 non-null   float64
#  20  percussive_var   6987 non-null   float64
#  21  centroid_mean    6987 non-null   float64
#  22  centroid_var     6987 non-null   float64
#  23  centroid_min     6987 non-null   float64
#  24  centroid_max     6987 non-null   float64
#  25  chroma_mean      6987 non-null   float64
#  26  chroma_var       6987 non-null   float64
#  27  chroma_min       6987 non-null   float64
#  28  chroma_max       6987 non-null   float64
#  29  tntz_mean        6987 non-null   float64
#  30  tntz_var         6987 non-null   float64
#  31  tntz_min         6987 non-null   float64
#  32  tntz_max         6987 non-null   float64
#  33  melspec_mean     6987 non-null   float64
#  34  melspec_var      6987 non-null   float64
#  35  melspec_min      6987 non-null   float64
#  36  melspec_max      6987 non-null   float64
#  37  rms_mean         6987 non-null   float64
#  38  rms_var          6987 non-null   float64
#  39  tempo            6987 non-null   float64
#  40  genre_y          6987 non-null   object
# dtypes: float64(39), object(2)
# memory usage: 2.2+ MB

# %%
genres = music_df['genre_y']
count = music_df['genre_y'].value_counts()

# %%
count
# Out:
# rock         743
# metal        740
# pop          729
# hiphop       721
# country      710
# blues        697
# classical    684
# disco        678
# reggae       665
# jazz         620
# Name: genre_y, dtype: int64

# %% [markdown]
# ## OneHotEncoding Genres

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
genres_df = music_df[['genre_y']]

# %%
ohe = OneHotEncoder(sparse = False)

genres_ohe = ohe.fit_transform(genres_df)

ohe_df = pd.DataFrame(genres_ohe, columns = ohe.get_feature_names_out(['genre_y']))

df = pd.concat([music_df, ohe_df], axis = 1)

df.drop(columns = ['genre_y'], inplace = True)

# %%
df.drop(columns = 'file_name', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6987 entries, 0 to 6986
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mfcc_mean          6987 non-null   float64
#  1   mfcc_var           6987 non-null   float64
#  2   mfcc_min           6987 non-null   float64
#  3   mfcc_max           6987 non-null   float64
#  4   mfcc1_mean         6987 non-null   float64
#  5   mfcc1_var          6987 non-null   float64
#  6   mfcc1_min          6987 non-null   float64
#  7   mfcc1_max          6987 non-null   float64
#  8   mfcc2_mean         6987 non-null   float64
#  9   mfcc2_var          6987 non-null   float64
#  10  mfcc2_min          6987 non-null   float64
#  11  mfcc2_max          6987 non-null   float64
#  12  delta_mean         6987 non-null   float64
#  13  delta_var          6987 non-null   float64
#  14  delta2_mean        6987 non-null   float64
#  15  delta2_var         6987 non-null   float64
#  16  harmonic_mean      6987 non-null   float64
#  17  harmonic_var       6987 non-null   float64
#  18  percussive_mean    6987 non-null   float64
#  19  percussive_var     6987 non-null   float64
#  20  centroid_mean      6987 non-null   float64
#  21  centroid_var       6987 non-null   float64
#  22  centroid_min       6987 non-null   float64
#  23  centroid_max       6987 non-null   float64
#  24  chroma_mean        6987 non-null   float64
#  25  chroma_var         6987 non-null   float64
#  26  chroma_min         6987 non-null   float64
#  27  chroma_max         6987 non-null   float64
#  28  tntz_mean          6987 non-null   float64
#  29  tntz_var           6987 non-null   float64
#  30  tntz_min           6987 non-null   float64
#  31  tntz_max           6987 non-null   float64
#  32  melspec_mean       6987 non-null   float64
#  33  melspec_var        6987 non-null   float64
#  34  melspec_min        6987 non-null   float64
#  35  melspec_max        6987 non-null   float64
#  36  rms_mean           6987 non-null   float64
#  37  rms_var            6987 non-null   float64
#  38  tempo              6987 non-null   float64
#  39  genre_y_blues      6987 non-null   float64
#  40  genre_y_classical  6987 non-null   float64
#  41  genre_y_country    6987 non-null   float64
#  42  genre_y_disco      6987 non-null   float64
#  43  genre_y_hiphop     6987 non-null   float64
#  44  genre_y_jazz       6987 non-null   float64
#  45  genre_y_metal      6987 non-null   float64
#  46  genre_y_pop        6987 non-null   float64
#  47  genre_y_reggae     6987 non-null   float64
#  48  genre_y_rock       6987 non-null   float64
# dtypes: float64(49)
# memory usage: 2.6 MB

# %% [markdown]
# ## Train-Test-Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(columns=['genre_y_blues', 'genre_y_classical', 'genre_y_country', 'genre_y_disco', 'genre_y_hiphop',
                     'genre_y_jazz', 'genre_y_metal', 'genre_y_pop', 'genre_y_reggae', 'genre_y_rock'])
y = df[['genre_y_blues', 'genre_y_classical', 'genre_y_country', 'genre_y_disco', 'genre_y_hiphop',
        'genre_y_jazz', 'genre_y_metal', 'genre_y_pop', 'genre_y_reggae', 'genre_y_rock']]

# %%
#train-test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42)

#validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42)

# %%
#normalizing
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_val_scaled = scaler.transform(X_val)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf.predict(X_test_scaled)

# %%
rf_accuracy = accuracy_score(y_test, rf_pred)
print('Accuracy:', rf_accuracy)
rf_precision = precision_score(y_test, rf_pred, average = 'macro')
print('Precision:',rf_precision)
rf_recall = recall_score(y_test, rf_pred, average = 'macro')
print('Recall:',rf_recall)
# Out:
# Accuracy: 0.592274678111588
# Precision: 0.9864275025295253
# Recall: 0.5929206291288474

# %%
rf_cm =confusion_matrix(y_test.values.argmax(axis=1), 
                        rf_pred.argmax(axis=1));
ConfusionMatrixDisplay(rf_cm).plot()

# %% [markdown]
# ### SVM GS Model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
#target variable into a binary matrix
y = y.idxmax(axis=1)

# %%
#redefining train-test-split
#train-test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42)

#validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42)

# %%
#normalizing
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_val_scaled = scaler.transform(X_val)

# %%
param = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
}

# %%
svm_model = SVC()
svm_gs = GridSearchCV(svm_model, param, cv=5, n_jobs=-1)
svm_gs.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
best_params = svm_gs.best_params_
print(best_params)
best_model = svm_gs.best_estimator_
print(best_model)
# Out:
# {'C': 10, 'kernel': 'rbf'}
# SVC(C=10)

# %%
svm_pred = best_model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, svm_pred)
print("Best Hyperparameters:", best_params)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, svm_pred))
# Out:
# Best Hyperparameters: {'C': 10, 'kernel': 'rbf'}
# Accuracy: 0.8912732474964234
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#     genre_y_blues       0.94      0.95      0.94       153
# genre_y_classical       0.90      0.91      0.91       133
#   genre_y_country       0.87      0.88      0.87       147
#     genre_y_disco       0.81      0.93      0.86       134
#    genre_y_hiphop       0.95      0.86      0.91       139
#      genre_y_jazz       0.80      0.83      0.82       127
#     genre_y_metal       0.93      0.93      0.93       139
#       genre_y_pop       0.88      0.86      0.87       143
#    genre_y_reggae       0.94      0.91      0.93       131
#      genre_y_rock       0.90      0.86      0.88       152
#
#          accuracy                           0.89      1398
#         macro avg       0.89      0.89      0.89      1398
#      weighted avg       0.89      0.89      0.89      1398

# %%
results = svm_gs.cv_results_

params = results['params']
mean_test_scores = results['mean_test_score']

labels = [f"{param['kernel']} (C={param['C']})" for param in params]

plt.figure(figsize=(10, 6))
plt.plot(labels, mean_test_scores, marker='o')
plt.xlabel('Hyperparameter Settings')
plt.ylabel('Mean Test Accuracy')
plt.title('Accuracy of SVM/SVC Model for Different Hyperparameter Settings')
plt.xticks(rotation=45, ha='right')
plt.grid()
plt.tight_layout()
plt.show()

# %%
svm_cm =confusion_matrix(y_test, 
                        svm_pred);
ConfusionMatrixDisplay(svm_cm).plot()

# %%
svm_accuracy = accuracy_score(y_test, svm_pred)
print('Accuracy:', svm_accuracy)
svm_precision = precision_score(y_test, svm_pred, average = 'macro')
print('Precission:',svm_precision)
svm_recall = recall_score(y_test, svm_pred, average = 'macro')
print('Recall:',svm_recall)
# Out:
# Accuracy: 0.8912732474964234
# Precission: 0.8924459735275725
# Recall: 0.8910223549493039

# %% [markdown]
# ### KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA

# %%
def cross_val(X_train, y_train, k, num_split = 20):

    X_train = X_train.values
    y_train = y_train.values
    
    score_train_list = []
    score_val_list = []
    
    for train_index, valid_index in KFold(n_splits = num_split).split(X_train):
       
        #train & validation splitting (folds)
        X_train_fold, X_val_fold = X_train[train_index], X_train[valid_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[valid_index]
        
        #scaling and fitting on the train/val fold 
        scaler = StandardScaler()
        X_tf_sc = scaler.fit_transform(X_train_fold)
        X_vld_sc = scaler.transform(X_val_fold)
        
        #creating and fitting knn 
        knn = KNeighborsClassifier(n_neighbors = k, metric = 'euclidean')
        knn.fit(X_tf_sc, y_train_fold)
        
        #scores
        acc_tr = knn.score(X_tf_sc, y_train_fold)
        acc_val = knn.score(X_vld_sc, y_val_fold)
        score_val_list.append(acc_val)
        score_train_list.append(acc_tr)
        
    return {'k': k, 'train': np.mean(score_train_list), 
                                    'validation': np.mean(score_val_list)}

# %%
crossval_df = pd.DataFrame(columns = ['k', 'train', 'validation'])

for k in range(1, 100):
    result = cross_val(X_train, y_train, k, 5)
    crossval_df = crossval_df.append(result, ignore_index=True)

# %%
crossval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   k           99 non-null     float64
#  1   train       99 non-null     float64
#  2   validation  99 non-null     float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
fig, ax = plt.subplots()
sns.lineplot(x = 'k', y = 'train', 
             data = crossval_df, 
             ax = ax, label = 'train')
sns.lineplot(x = 'k', y = 'validation', 
             data = crossval_df,
             ax = ax, label = 'validation')
ax.set_ylabel('Accuracy')
ax.set_title('5-fold CV tuning KNN')
plt.show()

# %%
crossval_df.iloc[crossval_df['validation'].idxmax()]
# Out:
# k             1.000000
# train         1.000000
# validation    0.866137
# Name: 0, dtype: float64

# %%
fulltrain_scaler = StandardScaler()
X_train_sc = fulltrain_scaler.fit_transform(X_train)
X_test_sc = fulltrain_scaler.transform(X_test)

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_sc)
X_test_pca = pca.transform(X_test_sc)

knn = KNeighborsClassifier(n_neighbors = 1)
knn.fit(X_train_sc, y_train)

knn_pred = knn.predict(X_test_sc)

# %%
knn_cm =confusion_matrix(y_test, 
                        knn_pred);
ConfusionMatrixDisplay(knn_cm).plot()

# %%
knn_accuracy = accuracy_score(y_test, knn_pred)
print('Accuracy:', knn_accuracy)
knn_precision = precision_score(y_test, knn_pred, average = 'macro')
print('Precission:',knn_precision)
knn_recall = recall_score(y_test, knn_pred, average = 'macro')
print('Recall:',knn_recall)
# Out:
# Accuracy: 0.8962804005722461
# Precission: 0.8959736172367772
# Recall: 0.8964095738610609

# %% [markdown]
# ## Models with Label Encoded Genres

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le = LabelEncoder()
music_df['genres_encoded'] = le.fit_transform(music_df['genre_y'])
music_df
# Out:
#                       file_name   mfcc_mean   mfcc_var   mfcc_min   mfcc_max  \
# 0        blues_69_segment_3.wav -135.282870  108.55024  13.028976  43.992382
# 1        blues_27_segment_4.wav  -91.254100  129.46655  -4.100496  45.220657
# 2        blues_54_segment_2.wav -191.496080  139.01646  11.991453  28.216597
# 3        blues_33_segment_1.wav -121.252815  123.47816  13.837003  28.114388
# 4     blues.00009_segment_2.wav -179.017550  138.22562 -30.912750  49.097755
# ...                         ...         ...        ...        ...        ...
# 6982   rock.00063_segment_2.wav -329.291080  139.87671  53.949990  17.256727
# 6983   rock.00004_segment_1.wav -167.203340  143.87451  12.607652  50.331360
# 6984      rock_36_segment_5.wav -269.519000  182.93669   9.128018   7.246886
# 6985      rock_45_segment_3.wav   39.978085   83.57576 -13.916237  31.080480
# 6986   rock.00090_segment_5.wav  -61.516655   99.30332 -26.088478  51.606903
#
#       mfcc1_mean  mfcc1_var  mfcc1_min  mfcc1_max  mfcc2_mean  ...   tntz_max  \
# 0      19.349297  20.206875  -1.577484   7.924092    1.519116  ...  12.485189
# 1       7.252443  16.338186   0.856577   0.009967    1.849428  ...  25.550907
# 2      -0.720076   7.438097   6.724214   6.649870   -0.442536  ...  10.569683
# 3       7.535354  15.141087  -3.699708   6.035746    0.958965  ...  63.396244
# 4     -24.154978   7.536681  -9.466703  10.459454  -20.845018  ...  17.512299
# ...          ...        ...        ...        ...         ...  ...        ...
# 6982   17.011780   9.052016   8.448787   2.826561    0.794122  ...   3.578562
# 6983   -0.389795  35.844570  -3.877623  16.113270   -9.246787  ...  18.517099
# 6984    6.279178  -1.525924  -8.689502   7.118561   -5.731806  ...   7.530454
# 6985    9.406852  10.378225  -1.250743   9.424727   -1.540306  ...  33.466774
# 6986  -32.753830  27.218400 -25.331880  17.409462  -16.120798  ...   4.966372
#
#       melspec_mean  melspec_var  melspec_min  melspec_max    rms_mean  \
# 0         9.272328     4.058815    12.436750     7.658901    3.056901
# 1        32.544811     9.085206    45.008915    46.512520  332.813812
# 2        13.037652     0.732540     0.283661     0.217625    0.489818
# 3        21.241156    20.493299    11.539183    11.035036   10.340260
# 4        12.562430    19.704935    44.741116    11.275842    0.719824
# ...            ...          ...          ...          ...         ...
# 6982      1.214767     1.100771     1.418536     1.387431    0.550771
# 6983      7.640218    10.939061    13.667733     5.664557    9.104764
# 6984      1.434070     0.361768     8.512635     1.714976    0.366517
# 6985     29.012289    35.188614    17.988277    31.572403   30.429539
# 6986      5.575272     4.648052     5.028794    10.276192   42.269131
#
#          rms_var      tempo  genre_y  genres_encoded
# 0      10.527410   7.565155    blues               0
# 1     129.471909   6.220565    blues               0
# 2       1.817209  13.725842    blues               0
# 3       9.673729   3.113847    blues               0
# 4       0.769180   3.037273    blues               0
# ...          ...        ...      ...             ...
# 6982    0.254566   0.513779     rock               9
# 6983    4.784025   4.133267     rock               9
# 6984    7.676395   1.953892     rock               9
# 6985   89.772820  35.103870     rock               9
# 6986   93.262970  69.886360     rock               9
#
# [6987 rows x 42 columns]

# %%
music_df.drop(columns = 'file_name', inplace = True)

# %%
X = music_df.drop(columns=['genres_encoded'])
y = music_df[['genres_encoded']]

# %%
#train-test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42)

#validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42)

# %%
#normalizing
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_val_scaled = scaler.transform(X_val)

# %%
param = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
}

# %%
svm_model = SVC()
svm_gs = GridSearchCV(svm_model, param, cv=5, n_jobs=-1)
svm_gs.fit(X_train_scaled, y_train)
# Out:
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kellyjara/anaconda3/envs/meowranda/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
best_params = svm_gs.best_params_
print(best_params)
best_model = svm_gs.best_estimator_
print(best_model)
# Out:
# {'C': 10, 'kernel': 'rbf'}
# SVC(C=10)

# %%
svm_pred = best_model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, svm_pred)
print("Best Hyperparameters:", best_params)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, svm_pred))
# Out:
# Best Hyperparameters: {'C': 10, 'kernel': 'rbf'}
# Accuracy: 0.8912732474964234
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       153
#            1       0.90      0.91      0.91       133
#            2       0.87      0.88      0.87       147
#            3       0.81      0.93      0.86       134
#            4       0.95      0.86      0.91       139
#            5       0.80      0.83      0.82       127
#            6       0.93      0.93      0.93       139
#            7       0.88      0.86      0.87       143
#            8       0.94      0.91      0.93       131
#            9       0.90      0.86      0.88       152
#
#     accuracy                           0.89      1398
#    macro avg       0.89      0.89      0.89      1398
# weighted avg       0.89      0.89      0.89      1398

# %%
svm_cm =confusion_matrix(y_test, 
                        svm_pred);
ConfusionMatrixDisplay(svm_cm).plot()

# %%
svm_accuracy = accuracy_score(y_test, svm_pred)
print('Accuracy:', svm_accuracy)
svm_precision = precision_score(y_test, svm_pred, average = 'macro')
print('Precission:',svm_precision)
svm_recall = recall_score(y_test, svm_pred, average = 'macro')
print('Recall:',svm_recall)
# Out:
# Accuracy: 0.8912732474964234
# Precission: 0.8924459735275725
# Recall: 0.8910223549493039

# %% [markdown]
# ## RNN LSTM Model - MFCC Features

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
mfcc = pd.read_csv('/Users/kellyjara/Desktop/Music_Classification/Data/mfcc.csv')
mfcc_df = pd.DataFrame(mfcc)
mfcc_df.head()
# Out:
#       0         1          2          3          4          5          6  \
# 0 -80.0 -5.373055  -6.322748  -7.905452 -16.608902  -9.817526 -11.959373
# 1 -80.0 -2.372444  -7.009487  -9.630412 -16.625700 -10.870303 -80.000000
# 2 -80.0 -1.871225 -11.246706  -8.025139 -12.312158 -11.786739 -10.196889
# 3 -80.0 -0.727390  -8.803666  -8.473115 -80.000000 -17.322235 -21.517681
# 4 -80.0 -1.198540 -22.873518 -12.717636 -80.000000 -10.542625 -80.000000
#
#            7          8          9  ...         55         56         57  \
# 0 -11.541872 -16.981678 -24.437847  ... -32.105938 -80.000000 -80.000000
# 1 -22.130718 -80.000000 -24.546850  ... -15.680571 -80.000000 -22.737434
# 2 -10.125285 -18.231392 -15.545910  ... -17.350794 -18.014662 -80.000000
# 3 -11.740473 -14.926936 -12.030826  ... -15.910123 -16.958126 -26.440540
# 4 -16.053448 -80.000000 -10.148211  ... -80.000000 -23.631989 -19.350496
#
#         58         59         60         61         62         63  label
# 0 -80.0000 -20.061068 -80.000000 -80.000000 -80.000000 -17.931187      0
# 1 -80.0000 -18.341770 -22.605436 -15.160420 -80.000000 -80.000000      0
# 2 -80.0000 -27.716154 -80.000000 -36.134840 -80.000000 -80.000000      0
# 3 -80.0000 -80.000000 -80.000000 -20.455551 -24.667341 -30.008951      0
# 4 -16.9179 -80.000000 -80.000000 -15.314171 -17.853876 -80.000000      0
#
# [5 rows x 65 columns]

# %%
X = mfcc_df.drop('label', axis=1).values
y = mfcc_df['label'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .20)

# %%
scaler = StandardScaler()

X_train_sc = scaler.fit_transform(np.array(X_train, dtype = float))
X_val_sc = scaler.transform(np.array(X_val, dtype = float))
X_test_sc = scaler.transform(np.array(X_test, dtype = float))

# %%
#without regularization

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.LSTM(units=64),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=32, activation='relu'),  
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model_1.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model1_hist = model_1.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 18/18 [==============================] - 13s 478ms/step - loss: 2.3022 - accuracy: 0.1046 - val_loss: 2.3007 - val_accuracy: 0.1247
# Epoch 2/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.2988 - accuracy: 0.1138 - val_loss: 2.2949 - val_accuracy: 0.1247
# Epoch 3/50
# 18/18 [==============================] - 7s 402ms/step - loss: 2.2905 - accuracy: 0.1181 - val_loss: 2.2826 - val_accuracy: 0.1329
# Epoch 4/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.2834 - accuracy: 0.1396 - val_loss: 2.2778 - val_accuracy: 0.1360
# Epoch 5/50
# 18/18 [==============================] - 8s 472ms/step - loss: 2.2771 - accuracy: 0.1406 - val_loss: 2.2797 - val_accuracy: 0.1401
# Epoch 6/50
# 18/18 [==============================] - 8s 454ms/step - loss: 2.2735 - accuracy: 0.1472 - val_loss: 2.2828 - val_accuracy: 0.1309
# Epoch 7/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.2681 - accuracy: 0.1501 - val_loss: 2.2675 - val_accuracy: 0.1319
# Epoch 8/50
# 18/18 [==============================] - 7s 417ms/step - loss: 2.2620 - accuracy: 0.1547 - val_loss: 2.2676 - val_accuracy: 0.1391
# Epoch 9/50
# 18/18 [==============================] - 7s 406ms/step - loss: 2.2577 - accuracy: 0.1633 - val_loss: 2.2638 - val_accuracy: 0.1585
# Epoch 10/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.2514 - accuracy: 0.1702 - val_loss: 2.2507 - val_accuracy: 0.1595
# Epoch 11/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.2446 - accuracy: 0.1695 - val_loss: 2.2627 - val_accuracy: 0.1595
# Epoch 12/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.2582 - accuracy: 0.1644 - val_loss: 2.2509 - val_accuracy: 0.1636
# Epoch 13/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.2367 - accuracy: 0.1838 - val_loss: 2.2420 - val_accuracy: 0.1830
# Epoch 14/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.2455 - accuracy: 0.1708 - val_loss: 2.2435 - val_accuracy: 0.1524
# Epoch 15/50
# 18/18 [==============================] - 7s 412ms/step - loss: 2.2310 - accuracy: 0.1800 - val_loss: 2.2350 - val_accuracy: 0.1789
# Epoch 16/50
# 18/18 [==============================] - 7s 408ms/step - loss: 2.2358 - accuracy: 0.1738 - val_loss: 2.2405 - val_accuracy: 0.1800
# Epoch 17/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.2217 - accuracy: 0.1915 - val_loss: 2.2233 - val_accuracy: 0.1820
# Epoch 18/50
# 18/18 [==============================] - 7s 411ms/step - loss: 2.2151 - accuracy: 0.1892 - val_loss: 2.2222 - val_accuracy: 0.1830
# Epoch 19/50
# 18/18 [==============================] - 7s 406ms/step - loss: 2.2110 - accuracy: 0.1892 - val_loss: 2.2311 - val_accuracy: 0.1616
# Epoch 20/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.2167 - accuracy: 0.1884 - val_loss: 2.2134 - val_accuracy: 0.1892
# Epoch 21/50
# 18/18 [==============================] - 7s 408ms/step - loss: 2.2040 - accuracy: 0.1879 - val_loss: 2.2278 - val_accuracy: 0.1646
# Epoch 22/50
# 18/18 [==============================] - 7s 406ms/step - loss: 2.2146 - accuracy: 0.1927 - val_loss: 2.2198 - val_accuracy: 0.2004
# Epoch 23/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.2147 - accuracy: 0.1848 - val_loss: 2.2255 - val_accuracy: 0.1810
# Epoch 24/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1976 - accuracy: 0.1981 - val_loss: 2.2127 - val_accuracy: 0.1881
# Epoch 25/50
# 18/18 [==============================] - 8s 438ms/step - loss: 2.2036 - accuracy: 0.1925 - val_loss: 2.2151 - val_accuracy: 0.1953
# Epoch 26/50
# 18/18 [==============================] - 7s 406ms/step - loss: 2.2005 - accuracy: 0.1943 - val_loss: 2.1951 - val_accuracy: 0.2014
# Epoch 27/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.1779 - accuracy: 0.2071 - val_loss: 2.1975 - val_accuracy: 0.2065
# Epoch 28/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1800 - accuracy: 0.2004 - val_loss: 2.1923 - val_accuracy: 0.2096
# Epoch 29/50
# 18/18 [==============================] - 8s 431ms/step - loss: 2.1717 - accuracy: 0.2030 - val_loss: 2.1826 - val_accuracy: 0.2076
# Epoch 30/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.1613 - accuracy: 0.2106 - val_loss: 2.1756 - val_accuracy: 0.2055
# Epoch 31/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.1883 - accuracy: 0.1958 - val_loss: 2.1924 - val_accuracy: 0.2147
# Epoch 32/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.1656 - accuracy: 0.2096 - val_loss: 2.1721 - val_accuracy: 0.2137
# Epoch 33/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1536 - accuracy: 0.2127 - val_loss: 2.1689 - val_accuracy: 0.2157
# Epoch 34/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.1541 - accuracy: 0.2094 - val_loss: 2.1562 - val_accuracy: 0.2157
# Epoch 35/50
# 18/18 [==============================] - 7s 410ms/step - loss: 2.1492 - accuracy: 0.2183 - val_loss: 2.1440 - val_accuracy: 0.2331
# Epoch 36/50
# 18/18 [==============================] - 7s 403ms/step - loss: 2.1498 - accuracy: 0.2163 - val_loss: 2.1540 - val_accuracy: 0.2137
# Epoch 37/50
# 18/18 [==============================] - 7s 411ms/step - loss: 2.1513 - accuracy: 0.2239 - val_loss: 2.1547 - val_accuracy: 0.2147
# Epoch 38/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.1392 - accuracy: 0.2206 - val_loss: 2.1484 - val_accuracy: 0.2321
# Epoch 39/50
# 18/18 [==============================] - 8s 419ms/step - loss: 2.1378 - accuracy: 0.2242 - val_loss: 2.1471 - val_accuracy: 0.2311
# Epoch 40/50
# 18/18 [==============================] - 7s 408ms/step - loss: 2.1348 - accuracy: 0.2224 - val_loss: 2.1522 - val_accuracy: 0.2198
# Epoch 41/50
# 18/18 [==============================] - 7s 410ms/step - loss: 2.1359 - accuracy: 0.2262 - val_loss: 2.1270 - val_accuracy: 0.2382
# Epoch 42/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1316 - accuracy: 0.2242 - val_loss: 2.1471 - val_accuracy: 0.2076
# Epoch 43/50
# 18/18 [==============================] - 8s 435ms/step - loss: 2.1295 - accuracy: 0.2324 - val_loss: 2.1449 - val_accuracy: 0.2270
# Epoch 44/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.1304 - accuracy: 0.2275 - val_loss: 2.1460 - val_accuracy: 0.2270
# Epoch 45/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.1317 - accuracy: 0.2244 - val_loss: 2.1288 - val_accuracy: 0.2331
# Epoch 46/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1259 - accuracy: 0.2267 - val_loss: 2.1489 - val_accuracy: 0.2331
# Epoch 47/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.1246 - accuracy: 0.2342 - val_loss: 2.1357 - val_accuracy: 0.2188
# Epoch 48/50
# 18/18 [==============================] - 8s 419ms/step - loss: 2.1218 - accuracy: 0.2311 - val_loss: 2.1364 - val_accuracy: 0.2219
# Epoch 49/50
# 18/18 [==============================] - 7s 409ms/step - loss: 2.1108 - accuracy: 0.2342 - val_loss: 2.1340 - val_accuracy: 0.2260
# Epoch 50/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.1210 - accuracy: 0.2308 - val_loss: 2.1224 - val_accuracy: 0.2454

# %%
loss, accuracy = model_1.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model_1.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 123/123 [==============================] - 4s 36ms/step - loss: 2.0686 - accuracy: 0.2513
# :loss: 2.068629503250122, accuracy: 0.2512781322002411
# 31/31 [==============================] - 1s 34ms/step - loss: 2.1224 - accuracy: 0.2454
# Test Loss: [2.1223812103271484, 0.24539877474308014]

# %%
plt.title('Loss')
plt.plot(model1_hist.history['loss'], label='train')
plt.plot(model1_hist.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(model1_hist.history['accuracy'], label = 'Train')
plt.plot(model1_hist.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %%
#with regularization

# %%
from tensorflow.keras.regularizers import L2

reg_lambda = 0.01 #reg strength

model_2 = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True,
                        kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.LSTM(units=64, kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=32, activation='relu', kernel_regularizer=L2(reg_lambda)),  
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=16, activation='relu',kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax', kernel_regularizer=L2(reg_lambda))
])

# %%
model_2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model2_hist = model_2.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 18/18 [==============================] - 13s 462ms/step - loss: 4.4027 - accuracy: 0.1043 - val_loss: 4.0097 - val_accuracy: 0.1125
# Epoch 2/50
# 18/18 [==============================] - 7s 396ms/step - loss: 3.7430 - accuracy: 0.1191 - val_loss: 3.4605 - val_accuracy: 0.1738
# Epoch 3/50
# 18/18 [==============================] - 8s 441ms/step - loss: 3.2832 - accuracy: 0.1439 - val_loss: 3.1028 - val_accuracy: 0.1585
# Epoch 4/50
# 18/18 [==============================] - 7s 401ms/step - loss: 2.9834 - accuracy: 0.1690 - val_loss: 2.8691 - val_accuracy: 0.1677
# Epoch 5/50
# 18/18 [==============================] - 8s 414ms/step - loss: 2.7843 - accuracy: 0.1636 - val_loss: 2.7112 - val_accuracy: 0.1513
# Epoch 6/50
# 18/18 [==============================] - 8s 450ms/step - loss: 2.6540 - accuracy: 0.1641 - val_loss: 2.5969 - val_accuracy: 0.1646
# Epoch 7/50
# 18/18 [==============================] - 8s 450ms/step - loss: 2.5512 - accuracy: 0.1774 - val_loss: 2.5180 - val_accuracy: 0.1616
# Epoch 8/50
# 18/18 [==============================] - 8s 461ms/step - loss: 2.4907 - accuracy: 0.1690 - val_loss: 2.4641 - val_accuracy: 0.1626
# Epoch 9/50
# 18/18 [==============================] - 8s 462ms/step - loss: 2.4492 - accuracy: 0.1708 - val_loss: 2.4296 - val_accuracy: 0.1636
# Epoch 10/50
# 18/18 [==============================] - 7s 403ms/step - loss: 2.4092 - accuracy: 0.1766 - val_loss: 2.3953 - val_accuracy: 0.1779
# Epoch 11/50
# 18/18 [==============================] - 7s 401ms/step - loss: 2.3840 - accuracy: 0.1746 - val_loss: 2.3809 - val_accuracy: 0.1748
# Epoch 12/50
# 18/18 [==============================] - 7s 399ms/step - loss: 2.3654 - accuracy: 0.1766 - val_loss: 2.3550 - val_accuracy: 0.1738
# Epoch 13/50
# 18/18 [==============================] - 8s 425ms/step - loss: 2.3389 - accuracy: 0.1846 - val_loss: 2.3324 - val_accuracy: 0.1769
# Epoch 14/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.3295 - accuracy: 0.1794 - val_loss: 2.3352 - val_accuracy: 0.1738
# Epoch 15/50
# 18/18 [==============================] - 7s 399ms/step - loss: 2.3114 - accuracy: 0.1902 - val_loss: 2.3222 - val_accuracy: 0.1881
# Epoch 16/50
# 18/18 [==============================] - 7s 403ms/step - loss: 2.3121 - accuracy: 0.1794 - val_loss: 2.3369 - val_accuracy: 0.1769
# Epoch 17/50
# 18/18 [==============================] - 7s 400ms/step - loss: 2.3061 - accuracy: 0.1830 - val_loss: 2.3069 - val_accuracy: 0.1912
# Epoch 18/50
# 18/18 [==============================] - 7s 402ms/step - loss: 2.2916 - accuracy: 0.1907 - val_loss: 2.2944 - val_accuracy: 0.1892
# Epoch 19/50
# 18/18 [==============================] - 7s 398ms/step - loss: 2.2845 - accuracy: 0.1922 - val_loss: 2.3035 - val_accuracy: 0.1902
# Epoch 20/50
# 18/18 [==============================] - 7s 400ms/step - loss: 2.2855 - accuracy: 0.1830 - val_loss: 2.2995 - val_accuracy: 0.1779
# Epoch 21/50
# 18/18 [==============================] - 7s 402ms/step - loss: 2.2819 - accuracy: 0.1887 - val_loss: 2.2866 - val_accuracy: 0.1677
# Epoch 22/50
# 18/18 [==============================] - 7s 404ms/step - loss: 2.2751 - accuracy: 0.1887 - val_loss: 2.2890 - val_accuracy: 0.1830
# Epoch 23/50
# 18/18 [==============================] - 7s 412ms/step - loss: 2.2702 - accuracy: 0.1897 - val_loss: 2.2844 - val_accuracy: 0.1748
# Epoch 24/50
# 18/18 [==============================] - 7s 398ms/step - loss: 2.2686 - accuracy: 0.1894 - val_loss: 2.2700 - val_accuracy: 0.1779
# Epoch 25/50
# 18/18 [==============================] - 7s 401ms/step - loss: 2.2700 - accuracy: 0.1897 - val_loss: 2.2659 - val_accuracy: 0.1912
# Epoch 26/50
# 18/18 [==============================] - 7s 402ms/step - loss: 2.2632 - accuracy: 0.1846 - val_loss: 2.2730 - val_accuracy: 0.1892
# Epoch 27/50
# 18/18 [==============================] - 7s 401ms/step - loss: 2.2663 - accuracy: 0.1866 - val_loss: 2.2758 - val_accuracy: 0.1902
# Epoch 28/50
# 18/18 [==============================] - 7s 397ms/step - loss: 2.2634 - accuracy: 0.1874 - val_loss: 2.2689 - val_accuracy: 0.1789
# Epoch 29/50
# 18/18 [==============================] - 7s 402ms/step - loss: 2.2628 - accuracy: 0.1915 - val_loss: 2.2674 - val_accuracy: 0.1851
# Epoch 30/50
# 18/18 [==============================] - 7s 405ms/step - loss: 2.2516 - accuracy: 0.1935 - val_loss: 2.2663 - val_accuracy: 0.1738
# Epoch 31/50
# 18/18 [==============================] - 7s 398ms/step - loss: 2.2694 - accuracy: 0.1869 - val_loss: 2.2675 - val_accuracy: 0.1769
# Epoch 32/50
# 18/18 [==============================] - 7s 400ms/step - loss: 2.2587 - accuracy: 0.1907 - val_loss: 2.2723 - val_accuracy: 0.1697
# Epoch 33/50
# 18/18 [==============================] - 7s 407ms/step - loss: 2.2551 - accuracy: 0.1894 - val_loss: 2.2659 - val_accuracy: 0.1738
# Epoch 34/50
# 18/18 [==============================] - 8s 453ms/step - loss: 2.2535 - accuracy: 0.1838 - val_loss: 2.2730 - val_accuracy: 0.1708
# Epoch 35/50
# 18/18 [==============================] - 8s 424ms/step - loss: 2.2506 - accuracy: 0.1897 - val_loss: 2.2591 - val_accuracy: 0.1840
# Epoch 36/50
# 18/18 [==============================] - 9s 476ms/step - loss: 2.2492 - accuracy: 0.1915 - val_loss: 2.2564 - val_accuracy: 0.1830
# Epoch 37/50
# 18/18 [==============================] - 8s 439ms/step - loss: 2.2446 - accuracy: 0.1981 - val_loss: 2.2642 - val_accuracy: 0.1830
# Epoch 38/50
# 18/18 [==============================] - 9s 497ms/step - loss: 2.2511 - accuracy: 0.1894 - val_loss: 2.2607 - val_accuracy: 0.1881
# Epoch 39/50
# 18/18 [==============================] - 9s 498ms/step - loss: 2.2494 - accuracy: 0.1879 - val_loss: 2.2683 - val_accuracy: 0.1677
# Epoch 40/50
# 18/18 [==============================] - 8s 425ms/step - loss: 2.2512 - accuracy: 0.1940 - val_loss: 2.2674 - val_accuracy: 0.1667
# Epoch 41/50
# 18/18 [==============================] - 8s 448ms/step - loss: 2.2512 - accuracy: 0.1892 - val_loss: 2.2649 - val_accuracy: 0.1840
# Epoch 42/50
# 18/18 [==============================] - 9s 488ms/step - loss: 2.2483 - accuracy: 0.1984 - val_loss: 2.2564 - val_accuracy: 0.1718
# Epoch 43/50
# 18/18 [==============================] - 8s 457ms/step - loss: 2.2525 - accuracy: 0.1902 - val_loss: 2.2692 - val_accuracy: 0.1881
# Epoch 44/50
# 18/18 [==============================] - 8s 433ms/step - loss: 2.2471 - accuracy: 0.1897 - val_loss: 2.2557 - val_accuracy: 0.1718
# Epoch 45/50
# 18/18 [==============================] - 8s 449ms/step - loss: 2.2462 - accuracy: 0.1904 - val_loss: 2.2527 - val_accuracy: 0.1840
# Epoch 46/50
# 18/18 [==============================] - 8s 439ms/step - loss: 2.2449 - accuracy: 0.1874 - val_loss: 2.2571 - val_accuracy: 0.1810
# Epoch 47/50
# 18/18 [==============================] - 8s 471ms/step - loss: 2.2453 - accuracy: 0.1915 - val_loss: 2.2502 - val_accuracy: 0.1851
# Epoch 48/50
# 18/18 [==============================] - 8s 435ms/step - loss: 2.2429 - accuracy: 0.1917 - val_loss: 2.2540 - val_accuracy: 0.1922
# Epoch 49/50
# 18/18 [==============================] - 8s 428ms/step - loss: 2.2417 - accuracy: 0.1938 - val_loss: 2.2574 - val_accuracy: 0.1820
# Epoch 50/50
# 18/18 [==============================] - 8s 429ms/step - loss: 2.2418 - accuracy: 0.1958 - val_loss: 2.2514 - val_accuracy: 0.1830

# %%
loss, accuracy = model_2.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model_2.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 123/123 [==============================] - 4s 33ms/step - loss: 2.2288 - accuracy: 0.1971
# :loss: 2.2288167476654053, accuracy: 0.1970858871936798
# 31/31 [==============================] - 1s 34ms/step - loss: 2.2514 - accuracy: 0.1830
# Test Loss: [2.2514002323150635, 0.18302658200263977]

# %%
plt.title('Loss')
plt.plot(model2_hist.history['loss'], label='train')
plt.plot(model2_hist.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(model2_hist.history['accuracy'], label = 'Train')
plt.plot(model2_hist.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %% [markdown]
# ## RNN LSTM Model - Spectrogram Featuers

# %%
spectrogram = pd.read_csv('/Users/kellyjara/Desktop/Music_Classification/Data/spectrogram.csv')
spec_df = pd.DataFrame(spectrogram)
spec_df.head()
# Out:
#            0          1          2          3          4          5  \
# 0 -14.251838 -13.122309 -17.378595 -19.016870 -19.089672 -17.880081
# 1 -12.428816 -17.256380 -18.799640 -19.021170 -19.608223 -22.834064
# 2  -7.222175  -7.465009  -9.467773 -15.350006 -24.655840 -22.813179
# 3 -13.839224 -13.039390 -18.652845 -29.813875 -20.888810 -16.828560
# 4 -19.986414 -22.005198 -18.739420 -18.591976 -15.725191 -22.208080
#
#            6          7          8          9  ...         55         56  \
# 0 -23.351181 -32.613007 -34.962963 -30.712912  ... -42.086105 -43.506080
# 1 -16.038242  -8.856348  -7.850418 -16.071945  ... -46.514070 -48.036354
# 2 -20.164675 -23.900408 -38.443485 -31.208973  ... -53.659267 -54.747837
# 3 -19.395489 -26.127188 -29.592663 -31.395107  ... -54.769577 -53.704840
# 4 -28.902262 -24.956005 -20.785997 -16.100275  ... -43.896725 -46.755570
#
#           57         58         59         60         61         62  \
# 0 -39.105614 -39.922960 -40.942955 -42.006210 -42.275425 -41.509205
# 1 -49.952156 -51.625275 -53.129400 -52.573864 -55.373750 -53.135370
# 2 -60.761158 -61.606316 -57.550750 -58.037480 -60.899445 -59.296980
# 3 -53.416397 -53.807476 -55.259468 -54.551190 -56.562866 -57.151756
# 4 -52.995403 -55.550240 -53.113583 -56.862617 -61.081062 -61.500280
#
#           63  label
# 0 -44.791510      0
# 1 -55.536080      0
# 2 -62.759600      0
# 3 -60.965576      0
# 4 -61.719170      0
#
# [5 rows x 65 columns]

# %%
X = spec_df.drop('label', axis=1).values
y = spec_df['label'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .20)

# %%
scaler = StandardScaler()

X_train_sc = scaler.fit_transform(np.array(X_train, dtype = float))
X_val_sc = scaler.transform(np.array(X_val, dtype = float))
X_test_sc = scaler.transform(np.array(X_test, dtype = float))

# %%
X_train_reshaped = X_train_sc.reshape((X_train_sc.shape[0], 1, X_train_sc.shape[1]))
X_test_reshaped = X_test_sc.reshape(X_test_sc.shape[0], 1, X_test_sc.shape[1])
X_val_reshaped = X_val_sc.reshape(X_val_sc.shape[0], 1, X_val_sc.shape[1])

# %%
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.LSTM(units=64),
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=32, activation='relu'),  
    tf.keras.layers.Dropout(0.2), 
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 19/19 [==============================] - 18s 562ms/step - loss: 2.2454 - accuracy: 0.1524 - val_loss: 2.1843 - val_accuracy: 0.2023
# Epoch 2/50
# 19/19 [==============================] - 10s 512ms/step - loss: 2.1597 - accuracy: 0.1911 - val_loss: 2.1066 - val_accuracy: 0.2338
# Epoch 3/50
# 19/19 [==============================] - 10s 522ms/step - loss: 2.1054 - accuracy: 0.2254 - val_loss: 2.0617 - val_accuracy: 0.2624
# Epoch 4/50
# 19/19 [==============================] - 9s 480ms/step - loss: 2.0728 - accuracy: 0.2474 - val_loss: 2.0424 - val_accuracy: 0.2719
# Epoch 5/50
# 19/19 [==============================] - 9s 491ms/step - loss: 2.0493 - accuracy: 0.2512 - val_loss: 2.0631 - val_accuracy: 0.2595
# Epoch 6/50
# 19/19 [==============================] - 10s 508ms/step - loss: 2.0390 - accuracy: 0.2519 - val_loss: 2.0337 - val_accuracy: 0.2863
# Epoch 7/50
# 19/19 [==============================] - 9s 495ms/step - loss: 2.0241 - accuracy: 0.2636 - val_loss: 2.0299 - val_accuracy: 0.2767
# Epoch 8/50
# 19/19 [==============================] - 10s 513ms/step - loss: 2.0222 - accuracy: 0.2605 - val_loss: 2.0138 - val_accuracy: 0.2834
# Epoch 9/50
# 19/19 [==============================] - 10s 519ms/step - loss: 2.0101 - accuracy: 0.2746 - val_loss: 2.0257 - val_accuracy: 0.2672
# Epoch 10/50
# 19/19 [==============================] - 10s 513ms/step - loss: 2.0206 - accuracy: 0.2650 - val_loss: 2.0124 - val_accuracy: 0.2691
# Epoch 11/50
# 19/19 [==============================] - 10s 510ms/step - loss: 2.0002 - accuracy: 0.2696 - val_loss: 2.0172 - val_accuracy: 0.2777
# Epoch 12/50
# 19/19 [==============================] - 10s 547ms/step - loss: 1.9943 - accuracy: 0.2705 - val_loss: 1.9937 - val_accuracy: 0.3034
# Epoch 13/50
# 19/19 [==============================] - 9s 485ms/step - loss: 1.9890 - accuracy: 0.2815 - val_loss: 2.0021 - val_accuracy: 0.2910
# Epoch 14/50
# 19/19 [==============================] - 10s 517ms/step - loss: 1.9811 - accuracy: 0.2753 - val_loss: 1.9825 - val_accuracy: 0.2987
# Epoch 15/50
# 19/19 [==============================] - 10s 522ms/step - loss: 1.9758 - accuracy: 0.2791 - val_loss: 1.9972 - val_accuracy: 0.2948
# Epoch 16/50
# 19/19 [==============================] - 8s 423ms/step - loss: 1.9750 - accuracy: 0.2853 - val_loss: 1.9745 - val_accuracy: 0.3101
# Epoch 17/50
# 19/19 [==============================] - 10s 514ms/step - loss: 1.9606 - accuracy: 0.2884 - val_loss: 1.9950 - val_accuracy: 0.2719
# Epoch 18/50
# 19/19 [==============================] - 11s 565ms/step - loss: 1.9699 - accuracy: 0.2791 - val_loss: 1.9682 - val_accuracy: 0.2968
# Epoch 19/50
# 19/19 [==============================] - 9s 488ms/step - loss: 1.9498 - accuracy: 0.2832 - val_loss: 1.9926 - val_accuracy: 0.2948
# Epoch 20/50
# 19/19 [==============================] - 12s 613ms/step - loss: 1.9523 - accuracy: 0.2855 - val_loss: 1.9575 - val_accuracy: 0.3111
# Epoch 21/50
# 19/19 [==============================] - 9s 484ms/step - loss: 1.9530 - accuracy: 0.2948 - val_loss: 1.9630 - val_accuracy: 0.2929
# Epoch 22/50
# 19/19 [==============================] - 10s 534ms/step - loss: 1.9541 - accuracy: 0.2906 - val_loss: 1.9523 - val_accuracy: 0.3025
# Epoch 23/50
# 19/19 [==============================] - 10s 529ms/step - loss: 1.9343 - accuracy: 0.2939 - val_loss: 1.9580 - val_accuracy: 0.3139
# Epoch 24/50
# 19/19 [==============================] - 9s 501ms/step - loss: 1.9413 - accuracy: 0.2915 - val_loss: 1.9453 - val_accuracy: 0.3120
# Epoch 25/50
# 19/19 [==============================] - 10s 507ms/step - loss: 1.9299 - accuracy: 0.2999 - val_loss: 1.9510 - val_accuracy: 0.3053
# Epoch 26/50
# 19/19 [==============================] - 10s 513ms/step - loss: 1.9144 - accuracy: 0.3053 - val_loss: 1.9485 - val_accuracy: 0.3063
# Epoch 27/50
# 19/19 [==============================] - 8s 408ms/step - loss: 1.9119 - accuracy: 0.2977 - val_loss: 1.9480 - val_accuracy: 0.2929
# Epoch 28/50
# 19/19 [==============================] - 8s 441ms/step - loss: 1.9144 - accuracy: 0.3051 - val_loss: 1.9347 - val_accuracy: 0.3082
# Epoch 29/50
# 19/19 [==============================] - 8s 433ms/step - loss: 1.8974 - accuracy: 0.3018 - val_loss: 1.9351 - val_accuracy: 0.3053
# Epoch 30/50
# 19/19 [==============================] - 8s 412ms/step - loss: 1.8983 - accuracy: 0.3082 - val_loss: 1.9246 - val_accuracy: 0.3092
# Epoch 31/50
# 19/19 [==============================] - 8s 425ms/step - loss: 1.8988 - accuracy: 0.3087 - val_loss: 1.9369 - val_accuracy: 0.3053
# Epoch 32/50
# 19/19 [==============================] - 8s 410ms/step - loss: 1.8882 - accuracy: 0.3084 - val_loss: 1.9221 - val_accuracy: 0.3006
# Epoch 33/50
# 19/19 [==============================] - 8s 412ms/step - loss: 1.8892 - accuracy: 0.3111 - val_loss: 1.9283 - val_accuracy: 0.3006
# Epoch 34/50
# 19/19 [==============================] - 8s 415ms/step - loss: 1.8711 - accuracy: 0.3213 - val_loss: 1.9412 - val_accuracy: 0.3101
# Epoch 35/50
# 19/19 [==============================] - 8s 412ms/step - loss: 1.8875 - accuracy: 0.3061 - val_loss: 1.9415 - val_accuracy: 0.2939
# Epoch 36/50
# 19/19 [==============================] - 8s 420ms/step - loss: 1.8857 - accuracy: 0.3158 - val_loss: 1.9482 - val_accuracy: 0.2920
# Epoch 37/50
# 19/19 [==============================] - 8s 416ms/step - loss: 1.8676 - accuracy: 0.3151 - val_loss: 1.9252 - val_accuracy: 0.3025
# Epoch 38/50
# 19/19 [==============================] - 8s 411ms/step - loss: 1.8650 - accuracy: 0.3187 - val_loss: 1.9160 - val_accuracy: 0.3092
# Epoch 39/50
# 19/19 [==============================] - 8s 408ms/step - loss: 1.8572 - accuracy: 0.3232 - val_loss: 1.9158 - val_accuracy: 0.2901
# Epoch 40/50
# 19/19 [==============================] - 8s 425ms/step - loss: 1.8601 - accuracy: 0.3249 - val_loss: 1.9225 - val_accuracy: 0.3197
# Epoch 41/50
# 19/19 [==============================] - 8s 409ms/step - loss: 1.8515 - accuracy: 0.3333 - val_loss: 1.9101 - val_accuracy: 0.3177
# Epoch 42/50
# 19/19 [==============================] - 8s 411ms/step - loss: 1.8319 - accuracy: 0.3321 - val_loss: 1.9100 - val_accuracy: 0.3120
# Epoch 43/50
# 19/19 [==============================] - 9s 472ms/step - loss: 1.8381 - accuracy: 0.3302 - val_loss: 1.9140 - val_accuracy: 0.3130
# Epoch 44/50
# 19/19 [==============================] - 8s 430ms/step - loss: 1.8161 - accuracy: 0.3416 - val_loss: 1.9170 - val_accuracy: 0.3053
# Epoch 45/50
# 19/19 [==============================] - 8s 415ms/step - loss: 1.8398 - accuracy: 0.3402 - val_loss: 1.9102 - val_accuracy: 0.2968
# Epoch 46/50
# 19/19 [==============================] - 8s 409ms/step - loss: 1.8187 - accuracy: 0.3387 - val_loss: 1.9088 - val_accuracy: 0.3244
# Epoch 47/50
# 19/19 [==============================] - 8s 410ms/step - loss: 1.8082 - accuracy: 0.3500 - val_loss: 1.9072 - val_accuracy: 0.3235
# Epoch 48/50
# 19/19 [==============================] - 8s 411ms/step - loss: 1.8036 - accuracy: 0.3418 - val_loss: 1.9266 - val_accuracy: 0.3120
# Epoch 49/50
# 19/19 [==============================] - 9s 465ms/step - loss: 1.8124 - accuracy: 0.3490 - val_loss: 1.9174 - val_accuracy: 0.3216
# Epoch 50/50
# 19/19 [==============================] - 8s 414ms/step - loss: 1.7874 - accuracy: 0.3593 - val_loss: 1.9125 - val_accuracy: 0.3273

# %%
loss, accuracy = model.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 131/131 [==============================] - 4s 34ms/step - loss: 1.7352 - accuracy: 0.3635
# :loss: 1.7352458238601685, accuracy: 0.3635496199131012
# 33/33 [==============================] - 1s 34ms/step - loss: 1.9125 - accuracy: 0.3273
# Test Loss: [1.9124633073806763, 0.3272900879383087]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()

# %%
#with regularization

reg_lambda = 0.01  # Regularization strength

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(X_train_sc.shape[1], 1), return_sequences=True,
                         kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(units=64, kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=32, activation='relu', kernel_regularizer=L2(reg_lambda)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax', kernel_regularizer=L2(reg_lambda))
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_sc, y_train, epochs=50, batch_size=225, validation_data=(X_val_sc, y_val))
# Out:
# Epoch 1/50
# 19/19 [==============================] - 14s 499ms/step - loss: 4.1858 - accuracy: 0.1601 - val_loss: 3.7686 - val_accuracy: 0.1765
# Epoch 2/50
# 19/19 [==============================] - 8s 408ms/step - loss: 3.5071 - accuracy: 0.1765 - val_loss: 3.2130 - val_accuracy: 0.2090
# Epoch 3/50
# 19/19 [==============================] - 8s 407ms/step - loss: 3.0425 - accuracy: 0.2016 - val_loss: 2.8456 - val_accuracy: 0.2223
# Epoch 4/50
# 19/19 [==============================] - 8s 405ms/step - loss: 2.7594 - accuracy: 0.2185 - val_loss: 2.6378 - val_accuracy: 0.2185
# Epoch 5/50
# 19/19 [==============================] - 8s 409ms/step - loss: 2.5643 - accuracy: 0.2202 - val_loss: 2.4943 - val_accuracy: 0.2443
# Epoch 6/50
# 19/19 [==============================] - 8s 406ms/step - loss: 2.4345 - accuracy: 0.2357 - val_loss: 2.3785 - val_accuracy: 0.2366
# Epoch 7/50
# 19/19 [==============================] - 8s 409ms/step - loss: 2.3454 - accuracy: 0.2390 - val_loss: 2.3093 - val_accuracy: 0.2567
# Epoch 8/50
# 19/19 [==============================] - 8s 407ms/step - loss: 2.3007 - accuracy: 0.2402 - val_loss: 2.2822 - val_accuracy: 0.2567
# Epoch 9/50
# 19/19 [==============================] - 8s 405ms/step - loss: 2.2601 - accuracy: 0.2495 - val_loss: 2.2309 - val_accuracy: 0.2576
# Epoch 10/50
# 19/19 [==============================] - 8s 416ms/step - loss: 2.2265 - accuracy: 0.2490 - val_loss: 2.2068 - val_accuracy: 0.2643
# Epoch 11/50
# 19/19 [==============================] - 8s 415ms/step - loss: 2.2013 - accuracy: 0.2526 - val_loss: 2.1898 - val_accuracy: 0.2567
# Epoch 12/50
# 19/19 [==============================] - 8s 414ms/step - loss: 2.1789 - accuracy: 0.2564 - val_loss: 2.1808 - val_accuracy: 0.2605
# Epoch 13/50
# 19/19 [==============================] - 8s 407ms/step - loss: 2.1725 - accuracy: 0.2610 - val_loss: 2.1797 - val_accuracy: 0.2719
# Epoch 14/50
# 19/19 [==============================] - 8s 407ms/step - loss: 2.1649 - accuracy: 0.2557 - val_loss: 2.1600 - val_accuracy: 0.2910
# Epoch 15/50
# 19/19 [==============================] - 8s 415ms/step - loss: 2.1456 - accuracy: 0.2660 - val_loss: 2.1590 - val_accuracy: 0.2615
# Epoch 16/50
# 19/19 [==============================] - 8s 440ms/step - loss: 2.1421 - accuracy: 0.2490 - val_loss: 2.1384 - val_accuracy: 0.2910
# Epoch 17/50
# 19/19 [==============================] - 8s 426ms/step - loss: 2.1240 - accuracy: 0.2667 - val_loss: 2.1337 - val_accuracy: 0.2872
# Epoch 18/50
# 19/19 [==============================] - 8s 421ms/step - loss: 2.1238 - accuracy: 0.2660 - val_loss: 2.1262 - val_accuracy: 0.2987
# Epoch 19/50
# 19/19 [==============================] - 8s 411ms/step - loss: 2.1154 - accuracy: 0.2708 - val_loss: 2.1153 - val_accuracy: 0.2987
# Epoch 20/50
# 19/19 [==============================] - 8s 411ms/step - loss: 2.1120 - accuracy: 0.2693 - val_loss: 2.1210 - val_accuracy: 0.2882
# Epoch 21/50
# 19/19 [==============================] - 8s 408ms/step - loss: 2.1067 - accuracy: 0.2691 - val_loss: 2.1177 - val_accuracy: 0.2767
# Epoch 22/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0954 - accuracy: 0.2755 - val_loss: 2.0984 - val_accuracy: 0.2891
# Epoch 23/50
# 19/19 [==============================] - 8s 429ms/step - loss: 2.0961 - accuracy: 0.2703 - val_loss: 2.1094 - val_accuracy: 0.2891
# Epoch 24/50
# 19/19 [==============================] - 8s 422ms/step - loss: 2.0922 - accuracy: 0.2772 - val_loss: 2.1186 - val_accuracy: 0.2824
# Epoch 25/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0887 - accuracy: 0.2798 - val_loss: 2.0994 - val_accuracy: 0.2815
# Epoch 26/50
# 19/19 [==============================] - 8s 417ms/step - loss: 2.0930 - accuracy: 0.2753 - val_loss: 2.0771 - val_accuracy: 0.3015
# Epoch 27/50
# 19/19 [==============================] - 8s 409ms/step - loss: 2.0736 - accuracy: 0.2851 - val_loss: 2.0857 - val_accuracy: 0.2910
# Epoch 28/50
# 19/19 [==============================] - 8s 408ms/step - loss: 2.0634 - accuracy: 0.2939 - val_loss: 2.0866 - val_accuracy: 0.2939
# Epoch 29/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0711 - accuracy: 0.2855 - val_loss: 2.1067 - val_accuracy: 0.2796
# Epoch 30/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0756 - accuracy: 0.2758 - val_loss: 2.0719 - val_accuracy: 0.3111
# Epoch 31/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0535 - accuracy: 0.2953 - val_loss: 2.0689 - val_accuracy: 0.2920
# Epoch 32/50
# 19/19 [==============================] - 8s 410ms/step - loss: 2.0553 - accuracy: 0.2913 - val_loss: 2.0507 - val_accuracy: 0.3149
# Epoch 33/50
# 19/19 [==============================] - 8s 428ms/step - loss: 2.0551 - accuracy: 0.2913 - val_loss: 2.0867 - val_accuracy: 0.3006
# Epoch 34/50
# 19/19 [==============================] - 8s 420ms/step - loss: 2.0652 - accuracy: 0.2846 - val_loss: 2.0715 - val_accuracy: 0.3082
# Epoch 35/50
# 19/19 [==============================] - 8s 421ms/step - loss: 2.0438 - accuracy: 0.2977 - val_loss: 2.0547 - val_accuracy: 0.2996
# Epoch 36/50
# 19/19 [==============================] - 8s 441ms/step - loss: 2.0424 - accuracy: 0.2896 - val_loss: 2.0767 - val_accuracy: 0.2987
# Epoch 37/50
# 19/19 [==============================] - 8s 417ms/step - loss: 2.0606 - accuracy: 0.2846 - val_loss: 2.0610 - val_accuracy: 0.3044
# Epoch 38/50
# 19/19 [==============================] - 8s 413ms/step - loss: 2.0335 - accuracy: 0.2989 - val_loss: 2.0475 - val_accuracy: 0.3139
# Epoch 39/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0294 - accuracy: 0.2982 - val_loss: 2.0527 - val_accuracy: 0.3139
# Epoch 40/50
# 19/19 [==============================] - 8s 407ms/step - loss: 2.0259 - accuracy: 0.2999 - val_loss: 2.0627 - val_accuracy: 0.2882
# Epoch 41/50
# 19/19 [==============================] - 8s 414ms/step - loss: 2.0377 - accuracy: 0.2953 - val_loss: 2.0664 - val_accuracy: 0.2920
# Epoch 42/50
# 19/19 [==============================] - 8s 409ms/step - loss: 2.0334 - accuracy: 0.2937 - val_loss: 2.0531 - val_accuracy: 0.3235
# Epoch 43/50
# 19/19 [==============================] - 8s 407ms/step - loss: 2.0359 - accuracy: 0.2987 - val_loss: 2.0410 - val_accuracy: 0.3139
# Epoch 44/50
# 19/19 [==============================] - 8s 410ms/step - loss: 2.0198 - accuracy: 0.3032 - val_loss: 2.0595 - val_accuracy: 0.3082
# Epoch 45/50
# 19/19 [==============================] - 8s 409ms/step - loss: 2.0215 - accuracy: 0.3008 - val_loss: 2.0453 - val_accuracy: 0.3158
# Epoch 46/50
# 19/19 [==============================] - 8s 408ms/step - loss: 2.0213 - accuracy: 0.3010 - val_loss: 2.0507 - val_accuracy: 0.3044
# Epoch 47/50
# 19/19 [==============================] - 8s 410ms/step - loss: 2.0299 - accuracy: 0.2977 - val_loss: 2.0504 - val_accuracy: 0.3149
# Epoch 48/50
# 19/19 [==============================] - 8s 410ms/step - loss: 2.0275 - accuracy: 0.3051 - val_loss: 2.0496 - val_accuracy: 0.3053
# Epoch 49/50
# 19/19 [==============================] - 8s 412ms/step - loss: 2.0088 - accuracy: 0.3132 - val_loss: 2.0286 - val_accuracy: 0.3111
# Epoch 50/50
# 19/19 [==============================] - 8s 413ms/step - loss: 2.0105 - accuracy: 0.3077 - val_loss: 2.0314 - val_accuracy: 0.3006

# %%
loss, accuracy = model.evaluate(X_train_sc, y_train)
print(f":loss: {loss}, accuracy: {accuracy}")
test_loss = model.evaluate(X_val_sc, y_val)
print(f'Test Loss: {test_loss}')
# Out:
# 131/131 [==============================] - 5s 36ms/step - loss: 1.9725 - accuracy: 0.3206
# :loss: 1.9725148677825928, accuracy: 0.3206106722354889
# 33/33 [==============================] - 1s 34ms/step - loss: 2.0314 - accuracy: 0.3006
# Test Loss: [2.031367540359497, 0.3005725145339966]

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], label = "Test")
plt.legend()
plt.show()
